# %% [markdown]
# <a href="https://colab.research.google.com/github/nutworker/qM-AI-L/blob/L_test/email-subject/model-tuning/AESLC_tuning_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
repository_url = 'https://github.com/nutworker/qM-AI-L'
# !git clone {repository_url}
# Out:
# fatal: destination path 'qM-AI-L' already exists and is not an empty directory.

# %%
# !apt-get install git
# !git clone https://github.com/ryanzhumich/AESLC

# !pip install transformers
# !pip install langchain_community
# !pip install langchain
# !pip install unstructured
# !pip install evaluate
# !pip install rouge-score # Installing rouge-score library (https://pypi.org/project/rouge-score/)

# !pip install accelerate -U

# !pip install transformers[torch]
# !pip install sacrebleu

# !pip install datasets nltk
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.4)
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.32.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.1+cu121)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.5.82)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.10.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.25.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.20.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
# Importing Libraries

# Data Handling
import pandas as pd
import tensorflow as tf
import numpy as np
import time
import seaborn as sns

from datasets import load_metric
from datasets import Dataset
import shutil

# # Data Visualization
# import plotly.express as px
# import plotly.graph_objs as go
# import plotly.subplots as sp
# from plotly.subplots import make_subplots
# import plotly.figure_factory as ff
# import plotly.io as pio
# from IPython.display import display
# from plotly.offline import init_notebook_mode
# init_notebook_mode(connected=True)

# # Statistics & Mathematics
# import scipy.stats as stats
# # import statsmodels.api as sm
# from scipy.stats import shapiro, skew, anderson, kstest, gaussian_kde,spearmanr
# import math

# Hiding warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install \
#     evaluate==0.4.0 \
#     rouge_score==0.1.2 \
#     loralib==0.1.1 \
#     peft==0.3.0 --quiet

# %%
# Transformers
from transformers import BartTokenizer, BartForConditionalGeneration      # BERT Tokenizer and architecture
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments         # These will help us to fine-tune our model
from transformers import pipeline                                         # Pipeline
from transformers import DataCollatorForSeq2Seq                           # DataCollator to batch the data
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration, DataCollatorForSeq2Seq, Trainer, TrainingArguments

# %%
import os
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

import evaluate

# %%
# from langchain_community.document_loaders import DirectoryLoader
# from langchain_community.document_loaders import DirectoryLoader

# %%
# # from langchain_community.document_loaders import GenericLoader
# from langchain_community.document_loaders.blob_loaders import FileSystemBlobLoader

# %%
# from langchain.document_loaders.text import TextLoader

# %%
dataset_df = pd.read_csv('/content/qM-AI-L/email-subject/model-tuning/train_emails.csv')

# %%
dataset_df
# Out:
#                     source                                               body  \
# 0         allen-p_inbox_20  Greg/Phillip,  Attached is the Grande Communic...
# 1         allen-p_inbox_28  Phillip & Keith  Attached is the first draw re...
# 2         allen-p_inbox_63  Your Internet Banking accounts are now setup a...
# 3         allen-p_inbox_64  To our IBS Customers that are still hanging in...
# 4         allen-p_inbox_65  Phillip Good Morning!\nI hope you had a wonder...
# ...                    ...                                                ...
# 14431  zufferli-j_inbox_43  This email is acknowledgement from the Power P...
# 14432  zufferli-j_inbox_44  This email is acknowledgement from the Power P...
# 14433  zufferli-j_inbox_46  John,  Further to the voice message that I lef...
# 14434   zufferli-j_inbox_8  Make sure that all curves are downloaded by th...
# 14435   zufferli-j_inbox_9  John:  Do you need Accumap day one?\nCarmen sa...
#
#                        subject  ann0  ann1  ann2  body_wcount  subj_wcount  \
# 0            Service Agreement   NaN   NaN   NaN           65            2
# 1               Bishops Corner   NaN   NaN   NaN          145            2
# 2             Internet Banking   NaN   NaN   NaN          250            2
# 3             Internet Banking   NaN   NaN   NaN          458            2
# 4      SMEs for expert stories   NaN   NaN   NaN           68            4
# ...                        ...   ...   ...   ...          ...          ...
# 14431               Power Pool   NaN   NaN   NaN          227            2
# 14432    Power Pool of Alberta   NaN   NaN   NaN          277            4
# 14433           Enron Security   NaN   NaN   NaN          148            2
# 14434        Simulation Curves   NaN   NaN   NaN           66            2
# 14435              IHS Accumap   NaN   NaN   NaN           35            2
#
#                                           cleaned_emails
# 0      gregphillip attached is the grande communicati...
# 1      phillip keith attached is the first draw reque...
# 2      your internet banking accounts are now setup a...
# 3      to our ibs customers that are still hanging in...
# 4      phillip good morning i hope you had a wonderfu...
# ...                                                  ...
# 14431  this email is acknowledgement from the power p...
# 14432  this email is acknowledgement from the power p...
# 14433  john further to the voice message that i left ...
# 14434  make sure that all curves are downloaded by th...
# 14435  john do you need accumap day one carmen said t...
#
# [14436 rows x 9 columns]

# %% [markdown]
# # **Test Train Split**

# %%
train_df, test_df = train_test_split(dataset_df, test_size=0.2, random_state=42)

# %%
train_df.shape, test_df.shape
# Out:
# ((11548, 9), (2888, 9))

# %%
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# %%
train_dataset, test_dataset
# Out:
# (Dataset({
#      features: ['source', 'body', 'subject', 'ann0', 'ann1', 'ann2', 'body_wcount', 'subj_wcount', 'cleaned_emails', '__index_level_0__'],
#      num_rows: 11548
#  }),
#  Dataset({
#      features: ['source', 'body', 'subject', 'ann0', 'ann1', 'ann2', 'body_wcount', 'subj_wcount', 'cleaned_emails', '__index_level_0__'],
#      num_rows: 2888
#  }))

# %%
#create a subset of dataset
train_dataset = train_dataset.filter(lambda example, index: index % 5 == 0, with_indices=True)
test_dataset = train_dataset.filter(lambda example, index: index % 5 == 0, with_indices=True)
# Out:
# Filter:   0%|          | 0/11548 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/2310 [00:00<?, ? examples/s]

# %%
train_dataset.shape, test_dataset.shape
# Out:
# ((2310, 10), (462, 10))

# %%
train_dataset['cleaned_emails'][0]
# Out:
# 'met early this morning with jack steward pres. of cma and keith mccrea lawyer for cma to follow up on the meeting that steve and i had with them regarding the proposal ken lay was pushing last week they like taking tx out of the mou they like getting dwr out of the power purchase business and they think that edisons mou needs a little haircut. mccrea pushed back initially on corenoncore why should it be mandatory to go the market but after much discussion they agreed that our idea for corenoncore has a lot of merit. our idea is that 1 the corenoncore would take effect in 1824 months when the markets settle and prices come down 2 everyone core and noncore should pay for dwrs past purchases since everyone consumed it 3 core customers should take iou generation qfs and dwr contracts which eliminates the cores net short position and 4 noncore would go to market and would not have to pay for any of dwrs going forward costs since core gets them in exchange for getting all the lowcost iou generation i told them we are still crunching the numbers to see what the rate effects would be and would share it with them when were done. while they are supportive of this approach and agreed that it would be useful to continue to flesh it out they are not convinced that it will get the necessary support to get passed. they are also withholding final judgment until they see all the numbers i.e. weve still got some work to do. they are very cynical about anything getting solved in california and are extremely upset about the pucs proposed rate decisions released by the judge and loretta lynch. they place very little trust in the governor or the legislature. interestingly the rate increase decisions coupled with calls in sacramento for an immediate move to corenoncore makes our proposal very attractive to cma. nonetheless they said that they will continue to engage and are willing to commit to continue meet to try to get californias mess resolved.'

# %% [markdown]
# **Load the pre-trained FLAN-T5 model and its tokenizer directly from HuggingFace. This is a small version of FLAN-T5. FLAN-T5 was released in the paper Scaling Instruction-Finetuned Language Models - it is an enhanced version of T5 that has been finetuned in a mixture of tasks. Setting torch_dtype=torch.bfloat16 specifies the memory type to be used by this model.**

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, GenerationConfig, TrainingArguments, Trainer

# %%
def print_number_of_trainable_model_parameters(model):
    trainable_model_params = 0
    all_model_params = 0
    for _, param in model.named_parameters():
        all_model_params += param.numel()
        if param.requires_grad:
            trainable_model_params += param.numel()
    return f"Trainable model parameters: {trainable_model_params}\nAll model parameters: {all_model_params}\nPercentage of trainable model parameters: {100 * trainable_model_params / all_model_params:.2f}%"

# %%
flan_t5_base_original_model = AutoModelForSeq2SeqLM.from_pretrained('google/flan-t5-base', torch_dtype=torch.bfloat16)
flan_t5_base_tokenizer = AutoTokenizer.from_pretrained('google/flan-t5-base')

print("For Model : FLAN-T5-Base \n",print_number_of_trainable_model_parameters(flan_t5_base_original_model))
# Out:
# For Model : FLAN-T5-Base
#  Trainable model parameters: 247577856
# All model parameters: 247577856
# Percentage of trainable model parameters: 100.00%

# %%
flan_t5_small_model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small", torch_dtype=torch.bfloat16)
# flan_t5_small_tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")

print("For Model : Flan-t5-small \n",print_number_of_trainable_model_parameters(flan_t5_small_model))
# Out:
# For Model : Flan-t5-small
#  Trainable model parameters: 76961152
# All model parameters: 76961152
# Percentage of trainable model parameters: 100.00%

# %%
# flan-t5-base vs. flan-t5-small parameters
247577856-76961152
# Out:
# 170616704

# %% [markdown]
# # **Test the Model with Zero Shot Inferencing**

# %% [markdown]
# **Using a pre-trained model from Hugging Face/sources - FLAN-T5-Base .**

# %%
index = 10

email = train_dataset['cleaned_emails'][index]
subject = train_dataset['subject'][index]

prompt = f"""
Generate the subject line for the following email.

Email:
{email}

Subject:
"""

inputs = flan_t5_base_tokenizer(prompt, return_tensors='pt')

# Move input tensors to the same device as the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
inputs = {k: v.to(flan_t5_base_original_model.device) for k, v in inputs.items()}


output = flan_t5_base_tokenizer.decode(
    flan_t5_base_original_model.generate(
        inputs["input_ids"],
        max_new_tokens=200,
    )[0],
    skip_special_tokens=True
)

dash_line = '-'.join('' for x in range(100))
print(dash_line)
print(f'INPUT PROMPT:\n{prompt}')
print(dash_line)
print(f'BASELINE ORIGINAL HUMAN ANNOTED SUBJECT LINE :\n{subject}\n')
print(dash_line)
print(f'FLAN-T5 MODEL GENERATION - ZERO SHOT SUBJECT LINE:\n{output}')
# Out:
# ---------------------------------------------------------------------------------------------------
# INPUT PROMPT:
#
# Generate the subject line for the following email.
#
# Email:
# many of you have asked about procedures to evaluate employee performance. we are finalizing a performance process designed to track and provide feedback on individual accomplishments for the benefit of each employee the company and the unsecured creditors committee. a very simple and straightforward online performance assessment system pas will allow us to automate parts of the process. pas will open next week on monday may 13 and remain open through friday may 24 2002. as an employee of a debtor company you should access the system and complete your self assessment by friday may 17 2002. your supervisor will review and approve submitted accomplishments and schedule a facetoface meeting to discuss your contributions offer feedback set priorities for the upcoming period discuss challenges and potential development opportunities and if applicable confirm your quarterly retention payout and project a target for the upcoming quarter. pas will be accessible through the hr global launch zone. well send a reminder with more details next week. in the meantime if you have questions about the process you can contact your hr representative.
#
# Subject:
#
# ---------------------------------------------------------------------------------------------------
# BASELINE ORIGINAL HUMAN ANNOTED SUBJECT LINE :
# Performance Process for All Employees in Debtor Companies
#
# ---------------------------------------------------------------------------------------------------
# FLAN-T5 MODEL GENERATION - ZERO SHOT SUBJECT LINE:
# Employee Performance Process

# %% [markdown]
# **Using a pre-trained model from Hugging Face etc- FLAN-T5-SMALL .**

# %%
inputs = flan_t5_base_tokenizer(prompt, return_tensors='pt')

# Move input tensors to the same device as the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# inputs = {k: v.to(device) for k, v in inputs.items()}


output = flan_t5_base_tokenizer.decode(
    flan_t5_small_model.generate(
        inputs["input_ids"],
        max_new_tokens=200,
    )[0],
    skip_special_tokens=True
)

dash_line = '-'.join('' for x in range(100))
print(dash_line)
print(f'INPUT PROMPT:\n{prompt}')
print(dash_line)
print(f'BASELINE ORIGINAL HUMAN ANNOTED SUBJECT LINE :\n{subject}\n')
print(dash_line)
print(f'FLAN-T5-SMALL MODEL GENERATION - ZERO SHOT SUBJECT LINE:\n{output}')
# Out:
# ---------------------------------------------------------------------------------------------------
# INPUT PROMPT:
#
# Generate the subject line for the following email.
#
# Email:
# many of you have asked about procedures to evaluate employee performance. we are finalizing a performance process designed to track and provide feedback on individual accomplishments for the benefit of each employee the company and the unsecured creditors committee. a very simple and straightforward online performance assessment system pas will allow us to automate parts of the process. pas will open next week on monday may 13 and remain open through friday may 24 2002. as an employee of a debtor company you should access the system and complete your self assessment by friday may 17 2002. your supervisor will review and approve submitted accomplishments and schedule a facetoface meeting to discuss your contributions offer feedback set priorities for the upcoming period discuss challenges and potential development opportunities and if applicable confirm your quarterly retention payout and project a target for the upcoming quarter. pas will be accessible through the hr global launch zone. well send a reminder with more details next week. in the meantime if you have questions about the process you can contact your hr representative.
#
# Subject:
#
# ---------------------------------------------------------------------------------------------------
# BASELINE ORIGINAL HUMAN ANNOTED SUBJECT LINE :
# Performance Process for All Employees in Debtor Companies
#
# ---------------------------------------------------------------------------------------------------
# FLAN-T5-SMALL MODEL GENERATION - ZERO SHOT SUBJECT LINE:
# Performance Process

# %% [markdown]
# **By testing with various models with the zero shot inferencing, we can see that the model struggles to extract the same subject line compared to the baseline subject, but it does pull out some important information from the email which indicates the models can be fine-tuned to the task at hand.**

# %% [markdown]
# # **Performing Full Fine-Tuning using FLAN-T5 BASE MODEL**

# %%
tokenizer = T5Tokenizer.from_pretrained('google/flan-t5-base')

# Define special tokens
special_tokens = {
    "additional_special_tokens": ["<EMAIL>", "</EMAIL>"]
}

# Add special tokens to the tokenizer
tokenizer.add_special_tokens(special_tokens)


# Load the model
model = T5ForConditionalGeneration.from_pretrained('google/flan-t5-base')

# Resize the model's embeddings to accommodate the new tokens
model.resize_token_embeddings(len(tokenizer))



def tokenize_function(examples):
    start_prompt = 'Generate the subject line for the following email.\n\nEmail:'
    end_prompt = '\nSubject:\n'
    inputs = [start_prompt + email + end_prompt for email in examples['body']]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding='max_length')

    labels = tokenizer(examples['subject'], max_length=50, truncation=True, padding='max_length')
    model_inputs['labels'] = labels['input_ids']
    return model_inputs

tokenized_dataset = train_dataset.map(tokenize_function, batched=True, remove_columns=train_dataset.column_names)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Map:   0%|          | 0/2310 [00:00<?, ? examples/s]

# %%
# Split the dataset into train and test
split_dataset = tokenized_dataset.train_test_split(test_size=0.2)
train_dataset = split_dataset['train']
test_dataset = split_dataset['test']

# %%
# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer
)

# Train the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='1386' max='1386' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1386/1386 17:08, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.405800</td>
#       <td>0.353899</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.294900</td>
#       <td>0.345977</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.316300</td>
#       <td>0.345001</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1386, training_loss=3.953941999919831, metrics={'train_runtime': 1031.0213, 'train_samples_per_second': 5.377, 'train_steps_per_second': 1.344, 'total_flos': 3795954683609088.0, 'train_loss': 3.953941999919831, 'epoch': 3.0})

# %%
# Load the ROUGE metric
rouge_metric = load_metric('rouge')

def calculate_rouge_scores(predictions, references):
    rouge_metric.add_batch(predictions=predictions, references=references)
    result = rouge_metric.compute()
    return {
        'rouge1': result['rouge1'].mid.fmeasure * 100,
        'rouge2': result['rouge2'].mid.fmeasure * 100,
        'rougeL': result['rougeL'].mid.fmeasure * 100
    }

# Generate predictions and calculate ROUGE scores
predictions = []
references = []

for example in test_dataset:
    input_ids = example['input_ids']
    input_ids = torch.tensor(input_ids).unsqueeze(0).to(device)  # Add batch dimension
    outputs = model.generate(input_ids)
    pred = tokenizer.decode(outputs[0], skip_special_tokens=True)
    ref = tokenizer.decode(example['labels'], skip_special_tokens=True)

    predictions.append(pred)
    references.append(ref)

# Calculate and print ROUGE scores for each test sample
rouge_scores = []
for pred, ref in zip(predictions, references):
    score = calculate_rouge_scores([pred], [ref])
    rouge_scores.append(score)
    print(f"Prediction: {pred}\nReference: {ref}\nROUGE Scores: {score}\n")

# Convert to DataFrame for better visualization
rouge_df = pd.DataFrame(rouge_scores)
rouge_df
# Out:
# Prediction: EFET
# Reference: ABN/AMRO
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: CSFB Markets
# Reference: Sovereign Bond Spreads, 7 September 2001
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: H&N
# Reference: H&N Gas LTd.
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: Accomplishments for January-April
# Reference: Projects/accomplishments
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Chicago
# Reference: Work in Chicago
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: GE plant
# Reference: tenaska invoices
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Questar Southern Trails Data Room
# Reference: Questar Southern Trails Data Room OCT 29 - 30 (Monday and Tuesday)
# ROUGE Scores: {'rouge1': 62.5, 'rouge2': 57.14285714285715, 'rougeL': 62.5}
#
# Prediction: Pompano
# Reference: Pompano Beach Energy Center
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Trip Information
# Reference: itinerary
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: How did it go?
# Reference: Good Morning
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Entergy Koch ConfirmLogic
# Reference: Entergy Koch ConfirmLogic
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: SoCal Gas Letter to CPUC
# Reference: SoCal Gas CPUC Proceeding
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 28.571428571428577, 'rougeL': 66.66666666666666}
#
# Prediction: "NAI at a Glance"
# Reference: NAI at a Glance June 2001
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 74.99999999999999, 'rougeL': 80.0}
#
# Prediction: Smith Barney
# Reference: Planning a meeting
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: AEC Confirm
# Reference: AEC Transaction Agreement
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Tenn Transport
# Reference: Tenn Transport
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: STCA Short on Peak
# Reference: STCA Forward Ob Position - 1/4
# ROUGE Scores: {'rouge1': 20.0, 'rouge2': 0.0, 'rougeL': 20.0}
#
# Prediction: Origination Hot List
# Reference: Q4 Plan
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: PBS Frontline Video
# Reference: PBS "Blackout" Broadcast Video Available
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Database
# Reference: Greetings
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Soccer fever
# Reference: get on the bandwagon
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: LC Status
# Reference: LC Update
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Meeting with Laura Luce
# Reference: Contract Review
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Roll Off Process for Gas Benchmark
# Reference: Rolloff Adjustment
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Wholesale Services Meetings
# Reference: Staff Meetings
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Telebears
# Reference: Class Registration
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: AESOP
# Reference: AESOP Language
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Duke Credit Language
# Reference: Duke Energy Marketing Limited Partnership
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: Netco Meeting
# Reference: Netco Meeting - Wednesday, January 2, 2002
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 33.333333333333336, 'rougeL': 50.0}
#
# Prediction: Dale Nesbitt
# Reference: Dale Nesbitt
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: archiving at the CES meeting tomorrow @ 2pm
# Reference: FYI
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: June Transco Transport
# Reference: Trco for June
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Enron Stock
# Reference: Buy Out?
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Hello!
# Reference: Where are you?
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Donor Appreciation Reception
# Reference: Donor Appreciation Event
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: Analysts and Associates Rotation
# Reference: ENA Analyst and Associate "Brownbag" Presentations
# ROUGE Scores: {'rouge1': 20.0, 'rouge2': 0.0, 'rougeL': 20.0}
#
# Prediction: New Hire
# Reference: Portland's IT New Hire annoucement
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 33.333333333333336, 'rougeL': 50.0}
#
# Prediction: DEP Response to Notice of Change
# Reference: Pompano
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: B Group
# Reference: Help!
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Thank you
# Reference: Thank You
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: ETS Staff Meeting
# Reference: MAY 29th ETS STAFF TIME CHANGE
# ROUGE Scores: {'rouge1': 44.44444444444444, 'rouge2': 28.571428571428577, 'rougeL': 44.44444444444444}
#
# Prediction: Counterparty Approval List for 12/14/01
# Reference: Credit Counterparty Approval List
# ROUGE Scores: {'rouge1': 54.54545454545454, 'rouge2': 44.44444444444444, 'rougeL': 54.54545454545454}
#
# Prediction: Repo
# Reference: Enron Credit Inc. ("ECI") consent
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: California
# Reference: Pescetti
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: 'I'm next'
# Reference: fwd
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: a party at my house
# Reference: central desk party
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: CGAS
# Reference: CGAS - Jerry Jordan Agreement
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Vacation
# Reference: Vacation - March 2, 3, and 6th
# ROUGE Scores: {'rouge1': 28.57142857142857, 'rouge2': 0.0, 'rougeL': 28.57142857142857}
#
# Prediction: Consulting Agreements
# Reference: Paper and pulp group status report
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Change Control Conference Call
# Reference: Change Control Conference Call 2/8/02
# ROUGE Scores: {'rouge1': 72.72727272727273, 'rouge2': 66.66666666666666, 'rougeL': 72.72727272727273}
#
# Prediction: ENA Legal Department Costs
# Reference: 2001 Allocations
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: New Stentofon Numbering Scheme
# Reference: Forward: Broadcast Message - Trading Floor Stentofons
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Engage
# Reference: Engage
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 0.0, 'rougeL': 100.0}
#
# Prediction: GDI - Tasks to be done
# Reference: StadiumS
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Clearinghouse Rules
# Reference: global futures exchanges
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: ECS Confirm
# Reference: Gas Purchase between ECS and ECC
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: Davis' consultants
# Reference: Davis Accuses Jones of "Witchhunt"
# ROUGE Scores: {'rouge1': 28.571428571428577, 'rouge2': 0.0, 'rougeL': 28.571428571428577}
#
# Prediction: WFEA
# Reference: Today's Hearing
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Email address
# Reference: CGAS Email
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Breakfast and Lunches
# Reference: Breakfast & Lunch - $5.00 ea
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: NN Interviews
# Reference: A few quotes for McKinsey's internal NewsNetwork?
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: United Way
# Reference: United Way and Boy Scouts of America
# ROUGE Scores: {'rouge1': 44.44444444444445, 'rouge2': 28.57142857142857, 'rougeL': 44.44444444444445}
#
# Prediction: California Blame Game
# Reference: Dan Walters: Blame game over California's energy crisis will continue for years
# ROUGE Scores: {'rouge1': 37.5, 'rouge2': 14.285714285714285, 'rougeL': 25.0}
#
# Prediction: Year-End 2001 PRC Process
# Reference: PRC Year-end 2001
# ROUGE Scores: {'rouge1': 88.8888888888889, 'rouge2': 57.14285714285715, 'rougeL': 66.66666666666666}
#
# Prediction: Socalgas Restructure
# Reference: Deal Struck in CA to Restructure Socalgas
# ROUGE Scores: {'rouge1': 44.44444444444445, 'rouge2': 0.0, 'rougeL': 22.222222222222225}
#
# Prediction: Donald Duhon
# Reference: Legal assistant Interviews
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Reassignment of Master Swap Agreements
# Reference: Reassignment of ISDA Master Agreements
# ROUGE Scores: {'rouge1': 80.00000000000001, 'rouge2': 25.0, 'rougeL': 80.00000000000001}
#
# Prediction: Houston Texans Season Tickets
# Reference: Houston Texans
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: Tenaska IV
# Reference: Tenaska IV 10/00
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: TW Commercial
# Reference: Proforma Signatures
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: NYSRC ICAP Working Group Meeting No. 15
# Reference: NYSRC ICAP W/G Mtg 8/29 location change
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 14.285714285714288, 'rougeL': 25.0}
#
# Prediction: Unocal Energy Trading, Inc.
# Reference: Revised Unocal Energy Trading Guaranty
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 57.14285714285715, 'rougeL': 66.66666666666666}
#
# Prediction: Exchange & Outlook Outages
# Reference: Tough Week
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Sorrento
# Reference: Meeting with Roger Westbrook
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Rate & Currency
# Reference: Rate & Currency $45.6 million
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: AMEX Southwest Fare Sale - Wednesday, March 21, 2002
# Reference: One-Day, Internet-Only Sale
# ROUGE Scores: {'rouge1': 15.384615384615385, 'rouge2': 0.0, 'rougeL': 15.384615384615385}
#
# Prediction: Great Lakes representative
# Reference: Great Lakes representative
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Draft of Master Agreement
# Reference: Revised responses to Interrogs. & Req. for Production for your re view.
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Letter to Jeff Skilling
# Reference: Your letter to Jeff Skilling
# ROUGE Scores: {'rouge1': 88.8888888888889, 'rouge2': 85.71428571428571, 'rougeL': 88.8888888888889}
#
# Prediction: Enron Kids
# Reference: Enron Kids
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Market Structure and Scheduling and Pricing Working Group Meeting
# Reference: Joint MSWG & S&PWG meeting, October 23, 2001
# ROUGE Scores: {'rouge1': 11.76470588235294, 'rouge2': 0.0, 'rougeL': 11.76470588235294}
#
# Prediction: Brazil
# Reference: Products for Trading in Brazil.
# ROUGE Scores: {'rouge1': 33.333333333333336, 'rouge2': 0.0, 'rougeL': 33.333333333333336}
#
# Prediction: Raymond James Research Group
# Reference: Power Research
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Draft Memo
# Reference: Municipality Draft Memo
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: Rebate for Orders for May
# Reference: "Datek Online Rebate Credit"
# ROUGE Scores: {'rouge1': 22.222222222222225, 'rouge2': 0.0, 'rougeL': 22.222222222222225}
#
# Prediction: Catalytica Swap and Option
# Reference: Raptor confirms
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Black Diamond Energy, Inc. and Shell Capital
# Reference: CAs for Black Diamond and Shell Capital
# ROUGE Scores: {'rouge1': 71.42857142857143, 'rouge2': 50.0, 'rougeL': 71.42857142857143}
#
# Prediction: Terry Thorn Retirement Reception
# Reference: Retirement Announcement - Terry Thorn
# ROUGE Scores: {'rouge1': 75.0, 'rouge2': 33.33333333333333, 'rougeL': 50.0}
#
# Prediction: MG London, Inc.
# Reference: MG acquisition and U.S. regulatory issues
# ROUGE Scores: {'rouge1': 20.0, 'rouge2': 0.0, 'rougeL': 20.0}
#
# Prediction: ICE Daily Index - New Hubs
# Reference: ** New N.A. Natural Gas Indices **
# ROUGE Scores: {'rouge1': 18.18181818181818, 'rouge2': 0.0, 'rougeL': 18.18181818181818}
#
# Prediction: Book Request Form
# Reference: book request
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: Transco Sims
# Reference: Transco Sims deal
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: Weekly Activity Report for 12/29/01
# Reference: Weekly Environemtnal Activity Report
# ROUGE Scores: {'rouge1': 54.54545454545454, 'rouge2': 22.22222222222222, 'rougeL': 54.54545454545454}
#
# Prediction: Netscape
# Reference: Problems on Saturday
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Enron and Enron
# Reference: Thos. Weisel/Chase
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: CPs
# Reference: CP Contract Information
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: ISC - Customer Service Survey
# Reference: ISC - Customer Service Survey
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: ACG Houston Chapter HBS Club
# Reference: ACG Invitation to HBS October 8 - Mayoral Candidate Panel Luncheon
# ROUGE Scores: {'rouge1': 26.666666666666668, 'rouge2': 0.0, 'rougeL': 26.666666666666668}
#
# Prediction: Supplements
# Reference: Dr. Schnieder
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: California Capacity Report for Friday's Gas Daily
# Reference: California Capacity Report for Week of 03/18-03/22
# ROUGE Scores: {'rouge1': 44.44444444444445, 'rouge2': 37.5, 'rougeL': 44.44444444444445}
#
# Prediction: Confidentiality / Non-Disclosure Agreement
# Reference: Confidentiality Agreement
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: GET RID OF DEBT NOW AND FOREVER! IT'S JUST A
# Reference: Get Out of Debt NOW! [65jzt]
# ROUGE Scores: {'rouge1': 47.05882352941177, 'rouge2': 26.666666666666668, 'rougeL': 47.05882352941177}
#
# Prediction: Lunch for the Committee
# Reference: ETS HOLIDAY PARTY
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Torpong
# Reference: resume of Torpong Cheevaprawatdomrong
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: ENA
# Reference: MEH
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: LC
# Reference: LC's
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: UBS Warburg Contacts
# Reference: Contact List
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Iceland NetClub Offers
# Reference: Lucky Fares 51 - from 129usd each way
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: New Kudlow Commentary
# Reference: KUDLOW.COM
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Chisholm LOI
# Reference: Comments from Chisholm
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Adopt a Kid - EWS Legal Gordon Elementary School
# Reference: Adopt a Kid - Reminder
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 40.0, 'rougeL': 50.0}
#
# Prediction: AEP Portland Position
# Reference: Farewell
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Charges for Vanadium Sample Check
# Reference: Fuel Oil Sample
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: Tiger Energy
# Reference: Tiger
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: The Enron Oral History Project Continues
# Reference: The Enron Oral History Project Continues
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Riskmantra
# Reference: Riskmantra vs. EGM
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: NETCo Forecasts
# Reference: 19 Month Forecast Review
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: PRC Attendee List
# Reference: PRC Attendee Lists
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: Football Pool
# Reference: results of the football pool
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: Expense Report
# Reference: Current Rotation info
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Sundance B and Sundance B4 PPA
# Reference: Split PPA
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: Mariner Energy, Inc.
# Reference: Notice of Rescheduled Special Telephonic Meeting of the BOD
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Presentation to Pure
# Reference: Pure Presentation - 2nd draft
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 0.0, 'rougeL': 28.571428571428577}
#
# Prediction: Lehman Bros. Holdings Inc.
# Reference: ISDA Master Agreement between Enron Corp. ("Enron") and Lehman Bros. Finance S.A. ("Lehman")
# ROUGE Scores: {'rouge1': 22.222222222222225, 'rouge2': 12.5, 'rougeL': 22.222222222222225}
#
# Prediction: California
# Reference: Senate Debating Unfairness of Singling Out Private-sector Sellers for Investigation
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: NDA - Enron North America Corp.
# Reference: NDA - IntercontinentalExchange
# ROUGE Scores: {'rouge1': 28.571428571428577, 'rouge2': 0.0, 'rougeL': 28.571428571428577}
#
# Prediction: Cantor
# Reference: cantor
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 0.0, 'rougeL': 100.0}
#
# Prediction: Hello
# Reference: Paris
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Urgent - Drugs Test Reminder
# Reference: Urgent - Drugs Test Reminder
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Wholesale Power Trading and Risk Systems Update
# Reference: Wholesale Power Systems Update
# ROUGE Scores: {'rouge1': 72.72727272727273, 'rouge2': 44.44444444444444, 'rougeL': 72.72727272727273}
#
# Prediction: Revised Contract
# Reference: WPS contract
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: WARNING: Your mailbox is approaching the size limit
# Reference: WARNING: Your mailbox is approaching the size limit
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Tomorrow
# Reference: stuff
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: CALP
# Reference: New Counterparty
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Enron Management Conference
# Reference: Enron Management Conference
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Cheryl's availability
# Reference: Scheduling & Conflicts
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Georgia Tech
# Reference: Internship
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Basis Roll Off
# Reference: Basis Rolloff
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Arbitration
# Reference: ISDA Agreements governed by English law
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Volume Management Group
# Reference: Greetings
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Transfer
# Reference: "Transfer" provision
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Interconnection
# Reference: Interconnection
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 0.0, 'rougeL': 100.0}
#
# Prediction: Lunch
# Reference: Lunch
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 0.0, 'rougeL': 100.0}
#
# Prediction: Annex A
# Reference: "Sara's changes to the omnibus"
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: ICE Access
# Reference: IntercontinentalExchange - Larry May
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Financial Trading Position
# Reference: Trading Posting
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Stumptown Bike and Brew
# Reference: Oct. 6 Bicycle Pub Crawl and Maylay (fwd)
# ROUGE Scores: {'rouge1': 16.666666666666664, 'rouge2': 0.0, 'rougeL': 16.666666666666664}
#
# Prediction: Condolences
# Reference: Enron and Prediction Company
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Assistant Trading Assistant Positions
# Reference: Assistant Trader Position Open
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: Term Sheet
# Reference: Kennedy Oil powder river renegotiation
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: EOL Hub
# Reference: EOL
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Hello
# Reference: hi
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Proposals for the CES meeting
# Reference: Options the Governor's Considering
# ROUGE Scores: {'rouge1': 20.000000000000004, 'rouge2': 0.0, 'rougeL': 20.000000000000004}
#
# Prediction: Norske Canada Downtime Database
# Reference: Norske Downtime for 1Q02
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: McKenzie & Co.
# Reference: Administration Wants to Talk to Me About CA's Gas Problems
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Morgan Stanley
# Reference: Morgan Stanley futures
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: Hi Daddy
# Reference: Daddy
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Enron Corp.
# Reference: REVISED-Tenaska IV-Cleburne Plant
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Organization Announcement
# Reference: Org. announcement
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Negative CTC Assignment
# Reference: Negative CTC assignment - memo to distributed
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 57.14285714285715, 'rougeL': 66.66666666666666}
#
# Prediction: weekend
# Reference: weekend option
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Draft order
# Reference: Fantast Basketball DRAFT TODAY @ 10:30
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: Redwood Deck
# Reference: your deck
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Nicor
# Reference: Nicor, Seotember, 2000 Production
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: T&D Model
# Reference: T&D Model
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Oglethorpe
# Reference: Oglethorpe
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 0.0, 'rougeL': 100.0}
#
# Prediction: Greetings
# Reference: TRAVEL TIME
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Tenn Z6
# Reference: Tenn Z6
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Contact List for Government Affairs
# Reference: "Let's Keep in Touch" Contact List
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 20.0, 'rougeL': 33.33333333333333}
#
# Prediction: Revised Coal and Ash Agreements
# Reference: Revised Coal and Ash Agreements
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Office Visit
# Reference: Super Saturday - Associate/Analyst Program
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: London Agreement
# Reference: Back to Back Agreement
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: 2001 Questia Balance Sheet
# Reference: Questia 2001 Balance Sheet
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 33.33333333333333, 'rougeL': 75.0}
#
# Prediction: CGAS invoices
# Reference: Estimates
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: outlines
# Reference: Other book summaries
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: High Chair Covers
# Reference: high chair covers
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Aquila Assignments
# Reference: Aquila Assignment
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Gilder Publishing - Friday Newsletter
# Reference: [gilder-technology-report] The Friday Letter 11.0
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Request for a Flat Screen
# Reference: Flat Screen Monitor
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 33.33333333333333, 'rougeL': 50.0}
#
# Prediction: Squaw bill
# Reference: Squaw Bill
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Enron Corp.
# Reference: WSJ - for confirmation
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Devon
# Reference: Devon and Panaco
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Iroquois Gas Transmission System L.P.
# Reference: Guaranty
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: 2002 Assessment
# Reference: MAIN invoices
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Entergy Supplement to Rate Update
# Reference: Entergy -- transmission service credits (ER01-1951-001)
# ROUGE Scores: {'rouge1': 16.666666666666664, 'rouge2': 0.0, 'rougeL': 16.666666666666664}
#
# Prediction: Dow Jones NP-15 and SP-15 Indexes
# Reference: Dow Jones Index - West Desk
# ROUGE Scores: {'rouge1': 30.76923076923077, 'rouge2': 18.181818181818183, 'rougeL': 30.76923076923077}
#
# Prediction: Southern Trails Interconnect
# Reference: Questar Southern Trails Interconnect - San Juan Co., NM
# ROUGE Scores: {'rouge1': 54.54545454545454, 'rouge2': 44.44444444444445, 'rougeL': 54.54545454545454}
#
# Prediction: Risk Management Solutions
# Reference: Domain Transfer Agreement
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Oneok Gas Marketing Company
# Reference: KN Marketing and Onoek
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: Wishing you the best
# Reference: Need a Bright Tenured Analyst?
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: MW Month Values
# Reference: EnPower Deal Entry question
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: 3rd Party Storage Procedures
# Reference: 3rd Party Storage Procedures - Initial Draft
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 74.99999999999999, 'rougeL': 80.0}
#
# Prediction: Global Finance
# Reference: Finance Support
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Outlook Training
# Reference: Outlook Migration
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Drivers License # & expiration date
# Reference: re[6]: RRSP Cont.
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: April 2000
# Reference: monthly forecast
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: ERMTP
# Reference: ERMTP status
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: EnronOnline Legal & Privacy Statement
# Reference: Legal & Privacy Statement
# ROUGE Scores: {'rouge1': 85.71428571428571, 'rouge2': 80.0, 'rougeL': 85.71428571428571}
#
# Prediction: Oglethorpe Power
# Reference: Oglethorpe
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Pilot Pilot
# Reference: Remote Access Pilot List
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: New Contracts
# Reference: Save the Date!
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Delano
# Reference: Delano Length for Saturday
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Knowledge Forum
# Reference: Knowledge Forum
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: ECTI
# Reference: DLJ International Capital
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Weather Derivatives Report
# Reference: Thank you note from Vancouver
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Deals for Monday - Friday
# Reference: Changed Deals - 460785, 460858, 460862
# ROUGE Scores: {'rouge1': 22.222222222222225, 'rouge2': 0.0, 'rougeL': 22.222222222222225}
#
# Prediction: ETA Qalhat
# Reference: ETA Notice.
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Argentina and Brazil
# Reference: "trading" activity in Argentina and Brazil
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 57.14285714285715, 'rougeL': 66.66666666666666}
#
# Prediction: Orig
# Reference: central orig
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: EES Deal Corrections
# Reference: Deal Change - Revision of last night's Deal Correction Report
# ROUGE Scores: {'rouge1': 15.384615384615383, 'rouge2': 0.0, 'rougeL': 15.384615384615383}
#
# Prediction: EES
# Reference: "Doorstep Reviews" - EES
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Grande Communications Service Agreement
# Reference: Service Agreement
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: Schedule 9 Loss Compensation Service Charges
# Reference: PNM Loss Charges, Schedule 9
# ROUGE Scores: {'rouge1': 72.72727272727272, 'rouge2': 22.222222222222225, 'rougeL': 36.36363636363636}
#
# Prediction: Best Wishes
# Reference: Our support/Best Wishes
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: Game
# Reference: Tennis
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Bay State Meter Bounce Charge
# Reference: Bay State Meter bounce fee
# ROUGE Scores: {'rouge1': 80.00000000000001, 'rouge2': 75.0, 'rougeL': 80.00000000000001}
#
# Prediction: P&Z
# Reference: P&Z
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Xcel Energy Inc.
# Reference: Xcel Energy Inc. to Northern States Power Company
# ROUGE Scores: {'rouge1': 54.54545454545454, 'rouge2': 44.44444444444445, 'rougeL': 54.54545454545454}
#
# Prediction: 2002 Sasquatch
# Reference: Sasquatch2002
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Staff Meeting
# Reference: Staff Meeting
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Midway LOI
# Reference: Midway LOI (prototype for Ft P)
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 33.333333333333336, 'rougeL': 50.0}
#
# Prediction: Quicksilver Resources, Inc.
# Reference: Quicksilver Resources
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: Acknowledgement and Termination Agreement
# Reference: El Paso/Sonat Acknowledgement and Termination Agreement
# ROUGE Scores: {'rouge1': 72.72727272727273, 'rouge2': 66.66666666666666, 'rougeL': 72.72727272727273}
#
# Prediction: Thank you
# Reference: Phone Call
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Presentation
# Reference: Customers - Getting the Requirements.ppt
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Out of Office
# Reference: Out of office
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: SE Book
# Reference: SE Book
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: EES load volume on 3/31, HE 6, SP-15
# Reference: Revised EES Spreadsheet 3/31
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 15.384615384615383, 'rougeL': 40.0}
#
# Prediction: Happy Birthday!
# Reference: Happy Birthday
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Final Schedule
# Reference: Final 11/30 for today
# ROUGE Scores: {'rouge1': 28.571428571428577, 'rouge2': 0.0, 'rougeL': 28.571428571428577}
#
# Prediction: Data Requests for Staff
# Reference: Staff's 2nd Set of Data Requests to LADWP and City of Pasadena
# ROUGE Scores: {'rouge1': 35.29411764705882, 'rouge2': 13.333333333333334, 'rougeL': 23.52941176470588}
#
# Prediction: 2000 Accomplishments
# Reference: Bullets for Stan's Roundtable
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Template
# Reference: Template for estimating Enron Capital needs
# ROUGE Scores: {'rouge1': 28.57142857142857, 'rouge2': 0.0, 'rougeL': 28.57142857142857}
#
# Prediction: California Tariff
# Reference: California Tariff
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Revised EES invoice
# Reference: Revised EES Invoice
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: CES Gas ENA
# Reference: CES Deal 282945
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: NRG
# Reference: NRG Power Marketing, Inc.
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: VEPCO Capacity and Energy Contract
# Reference: Comparison version
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: USGT Comparables
# Reference: response to PUC protest of USGT deal
# ROUGE Scores: {'rouge1': 22.222222222222225, 'rouge2': 0.0, 'rougeL': 22.222222222222225}
#
# Prediction: GE escrow agreement
# Reference: Escrow agreement
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: Presentation
# Reference: Asset Financing - Structured Finance Presentation
# ROUGE Scores: {'rouge1': 33.333333333333336, 'rouge2': 0.0, 'rougeL': 33.333333333333336}
#
# Prediction: Rogers
# Reference: Real Time Pricing In Effect
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Reliant Credit Reserve for September 2001
# Reference: Reliant Cal 04 Reserve for EOL
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 20.000000000000004, 'rougeL': 50.0}
#
# Prediction: Hello!
# Reference: You'd better not squeal!
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Kern Capacity Assignment and Payment
# Reference: Letter Agreement for Kern Capacity
# ROUGE Scores: {'rouge1': 40.00000000000001, 'rouge2': 25.0, 'rougeL': 40.00000000000001}
#
# Prediction: NYMEX Ex-Pilot Date
# Reference: NYMEX ACCESS
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Additional Objectives
# Reference: Fundy's Objectives
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Greetings
# Reference: checking in
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Curve Manager Security
# Reference: Curve File Security
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Click Paper.com
# Reference: Need Help!
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Confirm Issue
# Reference: N34222 with Tokyo Mitsubishi
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: GE Capital Services, Inc.
# Reference: NYPA ISDA Master
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Allen Center Garage Spaces
# Reference: Allen Center Availability
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: TW - Third Draft
# Reference: Transwestern Advice Protest
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: ABB Transformers
# Reference: ABB Transformer Purchase and Sale Agreement
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: Enron Corp.
# Reference: Westinghouse 501D5A damaged generator
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: FERC info
# Reference: CA ISO / CAL PX Information Related to 2000 Market Activity
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Supper club
# Reference: Supper Club
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: WARNING: Your mailbox is approaching the size limit
# Reference: WARNING: Your mailbox is approaching the size limit
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Today is my last day at Enron Canada Corp.
# Reference: Personal News
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Xtransco - IdleAire and Xtransco
# Reference: Xtransco Info
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: FERC Order on Capacity Contracts
# Reference: Upstream Capacity
# ROUGE Scores: {'rouge1': 28.571428571428577, 'rouge2': 0.0, 'rougeL': 28.571428571428577}
#
# Prediction: Mythology
# Reference: Thought You'd Enjoy This
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: CSX - CSX - CSX - CSX
# Reference: LLC Agreement
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Arbitration Cover Sheet
# Reference: Arbitration
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: POSREP 09 MAY 0900 UTC
# Reference: POSREP RESEND FOR 9 MAY
# ROUGE Scores: {'rouge1': 40.00000000000001, 'rouge2': 0.0, 'rougeL': 40.00000000000001}
#
# Prediction: UNCF Walk-a-thon
# Reference: UNCF Walk Collections
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: Banks
# Reference: ISDA requests and assorted items
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Food and Drinks
# Reference: Breakfast/Lunch/Snacks
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Sat party
# Reference: Party
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Edison Reverse Auction
# Reference: Reverse Auction
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: HPL Cost Savings
# Reference: 2001 Anticipated Budget Adjustments for HPL Sale
# ROUGE Scores: {'rouge1': 20.0, 'rouge2': 0.0, 'rougeL': 20.0}
#
# Prediction: DB Administrator
# Reference: DBA Administrator
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Sitara
# Reference: Reliant Energy Field Services Contract 96034155
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Edison and SoCalGas Summaries
# Reference: Edison and SoCalGas Advice Letter Summaries
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 50.0, 'rougeL': 80.0}
#
# Prediction: Confirmation
# Reference: Siemens deal - Parkway and Dawn basis offers (physical)
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Hello
# Reference: two potential projects at MIT
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: CGAS Questionnaire
# Reference: answer to cpuc protest
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Cristina
# Reference: Cristina
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 0.0, 'rougeL': 100.0}
#
# Prediction: New Date Bucket Format
# Reference: New Date Buckets
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: Energy Industry Survey - 12 Prizes Available
# Reference: Last Chance - - Energy Industry Survey Due in By Friday!
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 30.76923076923077, 'rougeL': 40.0}
#
# Prediction: New Address
# Reference: New Job and New Address
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: GISB
# Reference: GISB
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 0.0, 'rougeL': 100.0}
#
# Prediction: Out of Office
# Reference: Orange Bowl Bound on Wednesday, January 3
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Energy Central - Welcome to the Web!
# Reference: Welcome to Energy Central
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 50.0, 'rougeL': 40.0}
#
# Prediction: Online Trading
# Reference: Online Trading
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Hello!
# Reference: HEY, MAN!!
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: The Enron Oral History Project Continues
# Reference: The Enron Oral History Project Continues
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: New Schedule
# Reference: Part-time Schedule
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Photos
# Reference: Photos of Coz
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Cargill
# Reference: Cargill, Incorporated - WE NEED TO EXECUTE AN ISDA MASTER AGREEMENT
# ROUGE Scores: {'rouge1': 18.181818181818183, 'rouge2': 0.0, 'rougeL': 18.181818181818183}
#
# Prediction: BBQ
# Reference: party at PLove's
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Gallup Weekly Updates
# Reference: Gallup
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Headsets Unlimited
# Reference: Headsets
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: FERC tolling order on TW's request for rehearing
# Reference: PNM capacity: rehearing request
# ROUGE Scores: {'rouge1': 30.769230769230766, 'rouge2': 0.0, 'rougeL': 15.384615384615383}
#
# Prediction: California Power Prices
# Reference: California Power
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: LC Status
# Reference: LC Update
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Letter to Skilling
# Reference: The Newshour with Jim Lehrer sponsorship opportunity
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Conference Call - May 18th
# Reference: FRIDAY'S CONF CALL CANCELLED
# ROUGE Scores: {'rouge1': 22.222222222222225, 'rouge2': 0.0, 'rougeL': 22.222222222222225}
#
# Prediction: ENA
# Reference: Moore Global Investments, Ltds
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Assistant Legal Positions
# Reference: Job Posting
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Term Quotes - TermQuotes.com
# Reference: Low Cost Term Life Insurance. LX
# ROUGE Scores: {'rouge1': 20.0, 'rouge2': 0.0, 'rougeL': 20.0}
#
# Prediction: Changes to EnronOnline Agreement
# Reference: Aspect Resouces Committed Reserves TNCT
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Analyst Orientation
# Reference: Change in Presenter - Analyst Orientation
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: 11/30/2001 Books
# Reference: 11/30 Books
# ROUGE Scores: {'rouge1': 85.71428571428571, 'rouge2': 40.0, 'rougeL': 85.71428571428571}
#
# Prediction: Toshiba
# Reference: Meeting Request from Toshiba
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: GAD's Birthday
# Reference: Renowned Oysters
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: MF Update 11/11/01
# Reference: The Morning Market Call - Friday May 11th, 2001.
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Swank
# Reference: Mid Market
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: NLRB ruling on employee representation
# Reference: NLRB Ruling
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: REORIENTATION
# Reference: Reorientation
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 0.0, 'rougeL': 100.0}
#
# Prediction: Dale Osburn
# Reference: Wind Farm
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Revised Confirm
# Reference: Revised Confirm
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: NYPA ISDA
# Reference: NYPA ISDA
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Bank Meeting - Monday, November 19th
# Reference: Rescheduled: Enron Bank Meeting
# ROUGE Scores: {'rouge1': 44.44444444444445, 'rouge2': 28.571428571428577, 'rougeL': 44.44444444444445}
#
# Prediction: Final Form of Schedules
# Reference: Final Form of Schedules
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: EEI evangelism
# Reference: Report from the field
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: PG&E CEO
# Reference: Call from PG&E's CEO
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 28.571428571428577, 'rougeL': 66.66666666666666}
#
# Prediction: Mexico Counterparty Approval List
# Reference: Mexican Counterparties
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: La Fogata
# Reference: dinner reservations in san antonio
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Offshore Contract
# Reference: Letter Agreement
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Fundamentals Discussions
# Reference: Fundamentals Discussions
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: EBS
# Reference: Update
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: EWEB
# Reference: Finalization and Execution of ENA/EWEB documentation
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: 2002 Plan Forecast
# Reference: #4 - files you requested
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Curves
# Reference: Gas Curves
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: Thank you!
# Reference: 2001 Enron Field Opening Day Caps
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Power Indices
# Reference: Power Indices
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Force Majeure
# Reference: EnronOnline "Force Majeure" Language
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: First Amendment to ISDA Master Agreement
# Reference: National Bank of Canada
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Executive Summary Report Delay
# Reference: Executive Summary Information
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: Forward Template
# Reference: Enron Forward/Assignment confirms
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Sevil Reward
# Reference: Sevile
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Confirms
# Reference: TD crude prepay
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: EOL
# Reference: ETA Amendment - ANP Marketing Company
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: CGAS
# Reference: Swap Assignment Agreement - April 20 Draft
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: shingles
# Reference: Health Notice
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Asus dual-processer motherboard
# Reference: More DAW
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: CES
# Reference: Plans...
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: TiE Angel Forum - June 2nd
# Reference: "Reminder for TIE Angel Forum on June 2nd
# ROUGE Scores: {'rouge1': 76.92307692307693, 'rouge2': 54.54545454545454, 'rougeL': 76.92307692307693}
#
# Prediction: Power Prepayments
# Reference: Power Prepayments
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: GE Energy Services, Inc.
# Reference: RUSH APPR0VAL-Salomon Smith Barney AAA Energy Fund
# ROUGE Scores: {'rouge1': 16.666666666666664, 'rouge2': 0.0, 'rougeL': 16.666666666666664}
#
# Prediction: Cheryl
# ...
#
# Prediction: Revised CSA
# Reference: ABB - Comparision of Rev 10 vs. 12(final)
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: CES Energy Marketing & Trading
# Reference: utilities for 815 1/2 Cortlandt
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Wireless Spectrum Opportunity
# Reference: Wireless Spectrum - Creating a New Commodity Market
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 25.0, 'rougeL': 40.0}
#
# Prediction: Second Annual Holiday Ride of Lights and Dinner Celebration
# Reference: Holiday Right of Lights
# ROUGE Scores: {'rouge1': 46.15384615384615, 'rouge2': 18.181818181818183, 'rougeL': 46.15384615384615}
#
# Prediction: Agreement
# Reference: Raptor equity share swap
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: PG&E "Block II" Capacity
# Reference: PG&E Capacity
# ROUGE Scores: {'rouge1': 74.99999999999999, 'rouge2': 33.33333333333333, 'rougeL': 74.99999999999999}
#
# Prediction: Draft Master Memo
# Reference: org annoncement draft
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: CES
# Reference: Agreements
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: GE acceleration
# Reference: 10 AM and 12 PM Friday Conference Calls
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Jazz clubs in Chicago
# Reference: Mr. Chicago
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Black Hills
# Reference: Revised Black Hills
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: Omnibus
# Reference: 2 calls
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Jazz Fest
# Reference: Jazz Fest
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: E-Next turbine contract
# Reference: standard turbine contract
# ROUGE Scores: {'rouge1': 57.14285714285715, 'rouge2': 40.0, 'rougeL': 57.14285714285715}
#
# Prediction: April Deals
# Reference: Deals with Time Zones Amended
# ROUGE Scores: {'rouge1': 28.571428571428577, 'rouge2': 0.0, 'rougeL': 28.571428571428577}
#
# Prediction: Wildhorse Nomination Letter
# Reference: Wildhorse Nomination Letter
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Updated 11/12
# Reference: Sun Devil update meeting Monday 11/12 cancelled
# ROUGE Scores: {'rouge1': 36.36363636363637, 'rouge2': 22.222222222222225, 'rougeL': 36.36363636363637}
#
# Prediction: load discussion
# Reference: Southwestern Co-op
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Scuba Items
# Reference: Final Sale on Scuba Dooby Doo Items
# ROUGE Scores: {'rouge1': 44.44444444444445, 'rouge2': 0.0, 'rougeL': 44.44444444444445}
#
# Prediction: Conference Call on Thursday
# Reference: California Litigation Team Meeting - Conference Call on Thursday at 2:00
# ROUGE Scores: {'rouge1': 53.333333333333336, 'rouge2': 46.15384615384615, 'rougeL': 53.333333333333336}
#
# Prediction: CES documents
# Reference: EEI Canada and Ontario Product
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: KNE Web Site
# Reference: KNE web site problems
# ROUGE Scores: {'rouge1': 85.71428571428571, 'rouge2': 80.0, 'rougeL': 85.71428571428571}
#
# Prediction: PG&E National Energy Group - Parcel 8863 has been rejected
# Reference: PG&E eTrans Notification - Parcel 8863 has been rejected
# ROUGE Scores: {'rouge1': 73.68421052631578, 'rouge2': 58.82352941176471, 'rougeL': 73.68421052631578}
#
# Prediction: California lessons
# Reference: Hard Lessons from California
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Boston Capacity
# Reference: Boston Gas Release
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 0.0, 'rougeL': 40.0}
#
# Prediction: Accomplishments for the last year
# Reference: Accomplishments, Vince Kaminski
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: (1) Calpine Energy Services, Inc.
# Reference: ENA v. Miller
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Account
# Reference: Access
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: EES documents
# Reference: old bills
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Analysts
# Reference: Full Time Analysts
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: PG&E Open Season
# Reference: More Info: PG&E to Announce Open Season on Redwood and Baja Early Next Week
# ROUGE Scores: {'rouge1': 42.10526315789474, 'rouge2': 23.52941176470588, 'rougeL': 42.10526315789474}
#
# Prediction: Letter from Enron Corp.
# Reference: Kennedy Oil and Enron North America Corp.
# ROUGE Scores: {'rouge1': 36.36363636363637, 'rouge2': 0.0, 'rougeL': 36.36363636363637}
#
# Prediction: Sun Devil
# Reference: Gallup Final Docs
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Inactive Medical Benefits
# Reference: Medical Benefits for Inactive (Retired Employee)
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 28.571428571428577, 'rougeL': 44.44444444444444}
#
# Prediction: Energy Markets Institute Curriculum
# Reference: Energy Institute Curriculum
# ROUGE Scores: {'rouge1': 85.71428571428571, 'rouge2': 40.0, 'rougeL': 85.71428571428571}
#
# Prediction: FERC Comments on ICAP
# Reference: EPMI/EES draft ICAP paper
# ROUGE Scores: {'rouge1': 22.222222222222225, 'rouge2': 0.0, 'rougeL': 22.222222222222225}
#
# Prediction: Gas Turbine/Condition Monitoring Conference and Workshop
# Reference: Conference & workshop
# ROUGE Scores: {'rouge1': 44.44444444444445, 'rouge2': 0.0, 'rougeL': 44.44444444444445}
#
# Prediction: Un-allocated turbines
# Reference: Un-allocated Turbines
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Measurement Standards
# Reference: Engineering Standards for Measurement
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: Resume
# Reference: Updated Resume
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 66.66666666666666}
#
# Prediction: SW Bell
# Reference: SW Bell expense
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 66.66666666666666, 'rougeL': 80.0}
#
# Prediction: LatinSummit Sponsors
# Reference: LatinSummit - presented during the World Bank Annual Meetings
# ROUGE Scores: {'rouge1': 20.0, 'rouge2': 0.0, 'rougeL': 20.0}
#
# Prediction: O
# Reference: book
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: New Book Request Form
# Reference: John Arnold Crude Oil Deals
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: tickets
# Reference: GA GAME
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: rayfael
# Reference: AW: YEA!!!!!!!!!
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Over the Counter Prices
# Reference: Benelli Sport 10610
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: LC's
# Reference: Renewal of LC's
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: Greetings!
# Reference: Christmas Party
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: PGE Health and Welfare Benefits
# Reference: HEALTH & WELFARE BENEFITS
# ROUGE Scores: {'rouge1': 74.99999999999999, 'rouge2': 33.33333333333333, 'rougeL': 74.99999999999999}
#
# Prediction: EnronOnline
# Reference: Attendees at Newport Beach Workshop
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Enron MBA
# Reference: personal contact info
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Hello!
# Reference: Good Morning!!
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Mid Market Capacity
# Reference: East Power Mid-Market Org. Chart
# ROUGE Scores: {'rouge1': 44.44444444444444, 'rouge2': 28.571428571428577, 'rougeL': 44.44444444444444}
#
# Prediction: Hey
# Reference: How's School?
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Crestar and BP
# Reference: Crestar/ BP
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 0.0, 'rougeL': 80.0}
#
# Prediction: Parking and Mass Transit Resolution
# Reference: Parking & Mass Transit Resolution
# ROUGE Scores: {'rouge1': 88.8888888888889, 'rouge2': 57.14285714285715, 'rougeL': 88.8888888888889}
#
# Prediction: Vacation
# Reference: Out of the Office - March 2 and March 5
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Power Indices
# Reference: Power Indices
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Calc Sheet Deals
# Reference: Calc Sheet deals
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: e-mail
# Reference: sorema structure
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Letter from the President
# Reference: Cat Tale
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: California Power Exchange Corporation Deposition Subpoena
# Reference: Deposition Subpoena by the California State Senate Select Committee
# ROUGE Scores: {'rouge1': 40.0, 'rouge2': 15.384615384615385, 'rougeL': 26.666666666666668}
#
# Prediction: Intergen Closings
# Reference: CAED I and II closing (Intergen)
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: TCPL 2001-2002 Settlement Agreement
# Reference: NEB Approves TCPL Settlement
# ROUGE Scores: {'rouge1': 44.44444444444445, 'rouge2': 0.0, 'rougeL': 44.44444444444445}
#
# Prediction: YK 6095.1
# Reference: Kennedy Oil (Deal # 1178533) - Discrepancies
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Physindex Positions
# Reference: Physical Index positions in NCD
# ROUGE Scores: {'rouge1': 28.571428571428577, 'rouge2': 0.0, 'rougeL': 28.571428571428577}
#
# Prediction: QC1431.1 and QC1431.2 Basis offset
# Reference: Fwrd-Start Options
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Cost Center
# Reference: 2002 Direct Expense Plan
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: UT Letter
# Reference: Mastercard (G)
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Guest Lecture
# Reference: An Important Reminder
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: New e-mail address
# Reference: Web Alumni Directory Correction
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Enron Corp. guaranty
# Reference: Enron Corp. guaranty in favor of SITA
# ROUGE Scores: {'rouge1': 60.0, 'rouge2': 50.0, 'rougeL': 60.0}
#
# Prediction: Interview
# Reference: Enron Candidate
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Orig schedule
# Reference: orig schedule
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: Floating Price
# Reference: Puget Sound - put language (remainder of confirm has been faxed to you)
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Master Swap Agreements
# Reference: Financial Trading Documentation
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Weekly Reporting
# Reference: Public Water System Sampling Time Again
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Enron taps credit line; stock slides
# Reference: Saturday Articles
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: NYISO Back-Up Dispatch System Testing
# Reference: NYISO Back-Up Dispatch System Testing
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: SPA Language
# Reference: Future Fuel Sales to EcoElectrica by Enron
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Marie Heard
# Reference: "Sara's changes to the omnibus"
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: URGENT - URGENT - URGENT - URGENT
# Reference: Power of Attorney re UBS AG energy trading activities
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: TE South Pass
# Reference: TE South Pass at capacity
# ROUGE Scores: {'rouge1': 74.99999999999999, 'rouge2': 66.66666666666666, 'rougeL': 74.99999999999999}
#
# Prediction: Meeting with Mayor Brown
# Reference: Meeting with Mayor Willie L. Brown, Jr.
# ROUGE Scores: {'rouge1': 72.72727272727273, 'rouge2': 44.44444444444444, 'rougeL': 72.72727272727273}
#
# Prediction: PIRA Daily Demand Report 04/23/01
# Reference: PIRA's Daily Demand Forecast 04/23/01
# ROUGE Scores: {'rouge1': 80.0, 'rouge2': 46.15384615384615, 'rougeL': 80.0}
#
# Prediction: Emergency Contact Name
# Reference: Important Information Needed!!!!!!!!
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Access to your calendar
# Reference: Calendar Access
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: WARNING: Your mailbox is approaching the size limit
# Reference: WARNING: Your mailbox is approaching the size limit
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: forfeit deposit
# Reference: Looks like a forfeit
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: PG&E Update
# Reference: California slide for BOD package
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Todoroff
# Reference: Todoroff Prosecution--CONFIDENTIAL/SUBJECT TO ATTORNEY-CLIENT PRIVILEGE
# ROUGE Scores: {'rouge1': 22.22222222222222, 'rouge2': 0.0, 'rougeL': 22.22222222222222}
#
# Prediction: Deloitte Letter
# Reference: Deloitte Letter
# ROUGE Scores: {'rouge1': 100.0, 'rouge2': 100.0, 'rougeL': 100.0}
#
# Prediction: ena guarantee
# Reference: Centrica Guarantee
# ROUGE Scores: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0}
#
# Prediction: Draft of Master Agreement
# Reference: draft org memo
# ROUGE Scores: {'rouge1': 28.571428571428577, 'rouge2': 0.0, 'rougeL': 28.571428571428577}
#
# Prediction: EWEB
# Reference: bond counsel opinion
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Summer Camp
# Reference: Reminder
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Palo verde Position
# Reference: Length at PV heavy for the 20th
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Stack Manager
# Reference: New Stack Manager ID
# ROUGE Scores: {'rouge1': 66.66666666666666, 'rouge2': 50.0, 'rougeL': 66.66666666666666}
#
# Prediction: Non-Solicitations
# Reference: Approval of a Non-Solicitation Provision
# ROUGE Scores: {'rouge1': 25.0, 'rouge2': 0.0, 'rougeL': 25.0}
#
# Prediction: NG, Rpt, Hu, cl, rpt,
# Reference: commitment of traders 2/1
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Energy Capital Resources
# Reference: C-Gas
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Garden State Paper Services Agreement
# Reference: Garden State Paper
# ROUGE Scores: {'rouge1': 74.99999999999999, 'rouge2': 66.66666666666666, 'rougeL': 74.99999999999999}
#
# Prediction: Conroe
# Reference: sunday
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: WestLB
# Reference: ABB to do list
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Outsourcing IT
# Reference: IT Plans for Estate
# ROUGE Scores: {'rouge1': 33.33333333333333, 'rouge2': 0.0, 'rougeL': 33.33333333333333}
#
# Prediction: "What we do in life echoes through eternity"
# Reference: American Thanksgiving
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#
# Prediction: Hello
# Reference: venture
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}
#         rouge1  rouge2     rougeL
# 0     0.000000     0.0   0.000000
# 1     0.000000     0.0   0.000000
# 2    66.666667    50.0  66.666667
# 3    33.333333     0.0  33.333333
# 4    50.000000     0.0  50.000000
# ..         ...     ...        ...
# 457   0.000000     0.0   0.000000
# 458   0.000000     0.0   0.000000
# 459  33.333333     0.0  33.333333
# 460   0.000000     0.0   0.000000
# 461   0.000000     0.0   0.000000
#
# [462 rows x 3 columns]

# %%
# !pip install rouge-score
from rouge_score import rouge_scorer

scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.4)

# %%
small_test_df = test_df.sample(n=10, random_state=42)

# %%
small_test_df
# Out:
#                         source  \
# 6379           lay-k_inbox_371
# 12129     skilling-j_inbox_350
# 10080    salisbury-h_inbox_171
# 2534       delainey-d_sent_383
# 11347    shackleton-s_sent_393
# 4786         jones-t_inbox_455
# 9099   perlingiere-d_sent_2354
# 3780         giron-d_inbox_421
# 11931    skilling-j_inbox_1303
# 2626       delainey-d_sent_820
#
#                                                     body  \
# 6379   Good afternoon.\nThis email serves as a remind...
# 12129  Jeff:  The whole team and I very much enjoyed ...
# 10080  All, \t We had a piece computer equipment that...
# 2534   Please note time change for the QBR to be held...
# 11347  I am forwarding to you guidelines prepared for...
# 4786   Legal friends -   Patrick and I met with Jason...
# 9099   Jill:   As discussed,  attached is a GISB draf...
# 3780   Is the closest hotel to the Enron office the D...
# 11931  Please forward this information to any one you...
# 2626   Marty, looks like this nut may have some fruit...
#
#                                                  subject  ann0  ann1  ann2  \
# 6379      REMINDER - OCTOBER 24 BOARD MEETING - REMINDER   NaN   NaN   NaN
# 12129                           June 1 Deep Dive/Houston   NaN   NaN   NaN
# 10080  Equip Missing! LINKSYS EZXS88W ETHERFAST 10/10...   NaN   NaN   NaN
# 2534                          Friday East Mid Market QBR   NaN   NaN   NaN
# 11347                                  trader guidelines   NaN   NaN   NaN
# 4786                                      Credit Annexes   NaN   NaN   NaN
# 9099                Pioneer Natural Resources, USA, Inc.   NaN   NaN   NaN
# 3780                Travel Plans for Monday November 12?   NaN   NaN   NaN
# 11931          Energy Derivatives/Power Trading Seminars   NaN   NaN   NaN
# 2626                      Enron Direct Canada-First Deal   NaN   NaN   NaN
#
#        body_wcount  subj_wcount  \
# 6379           131            8
# 12129          417            4
# 10080           71           10
# 2534            43            5
# 11347          113            2
# 4786           198            2
# 9099            50            5
# 3780            91            6
# 11931           58            4
# 2626            41            4
#
#                                           cleaned_emails
# 6379   good afternoon. this email serves as a reminde...
# 12129  jeff the whole team and i very much enjoyed ou...
# 10080  all we had a piece computer equipment that has...
# 2534   please note time change for the qbr to be held...
# 11347  i am forwarding to you guidelines prepared for...
# 4786   legal friends patrick and i met with jason wil...
# 9099   jill as discussed attached is a gisb draft for...
# 3780   is the closest hotel to the enron office the d...
# 11931  please forward this information to any one you...
# 2626   marty looks like this nut may have some fruit....

# %%
def generate_subject_line(email_body):
    inputs = tokenizer("Generate the subject line for the following email.: " + email_body, return_tensors="pt", max_length=512, truncation=True)
    # Move inputs to the same device as the model
    inputs = {k: v.to(model.device) for k, v in inputs.items()}
    # Access input_ids as a key in the dictionary
    outputs = model.generate(inputs['input_ids'], max_length=128, num_beams=4, early_stopping=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
small_test_df['generated_subject_line'] = small_test_df['cleaned_emails'].apply(generate_subject_line)
small_test_df
# Out:
#                         source  \
# 6379           lay-k_inbox_371
# 12129     skilling-j_inbox_350
# 10080    salisbury-h_inbox_171
# 2534       delainey-d_sent_383
# 11347    shackleton-s_sent_393
# 4786         jones-t_inbox_455
# 9099   perlingiere-d_sent_2354
# 3780         giron-d_inbox_421
# 11931    skilling-j_inbox_1303
# 2626       delainey-d_sent_820
#
#                                                     body  \
# 6379   Good afternoon.\nThis email serves as a remind...
# 12129  Jeff:  The whole team and I very much enjoyed ...
# 10080  All, \t We had a piece computer equipment that...
# 2534   Please note time change for the QBR to be held...
# 11347  I am forwarding to you guidelines prepared for...
# 4786   Legal friends -   Patrick and I met with Jason...
# 9099   Jill:   As discussed,  attached is a GISB draf...
# 3780   Is the closest hotel to the Enron office the D...
# 11931  Please forward this information to any one you...
# 2626   Marty, looks like this nut may have some fruit...
#
#                                                  subject  ann0  ann1  ann2  \
# 6379      REMINDER - OCTOBER 24 BOARD MEETING - REMINDER   NaN   NaN   NaN
# 12129                           June 1 Deep Dive/Houston   NaN   NaN   NaN
# 10080  Equip Missing! LINKSYS EZXS88W ETHERFAST 10/10...   NaN   NaN   NaN
# 2534                          Friday East Mid Market QBR   NaN   NaN   NaN
# 11347                                  trader guidelines   NaN   NaN   NaN
# 4786                                      Credit Annexes   NaN   NaN   NaN
# 9099                Pioneer Natural Resources, USA, Inc.   NaN   NaN   NaN
# 3780                Travel Plans for Monday November 12?   NaN   NaN   NaN
# 11931          Energy Derivatives/Power Trading Seminars   NaN   NaN   NaN
# 2626                      Enron Direct Canada-First Deal   NaN   NaN   NaN
#
#        body_wcount  subj_wcount  \
# 6379           131            8
# 12129          417            4
# 10080           71           10
# 2534            43            5
# 11347          113            2
# 4786           198            2
# 9099            50            5
# 3780            91            6
# 11931           58            4
# 2626            41            4
#
#                                           cleaned_emails  \
# 6379   good afternoon. this email serves as a reminde...
# 12129  jeff the whole team and i very much enjoyed ou...
# 10080  all we had a piece computer equipment that has...
# 2534   please note time change for the qbr to be held...
# 11347  i am forwarding to you guidelines prepared for...
# 4786   legal friends patrick and i met with jason wil...
# 9099   jill as discussed attached is a gisb draft for...
# 3780   is the closest hotel to the enron office the d...
# 11931  please forward this information to any one you...
# 2626   marty looks like this nut may have some fruit....
#
#               generated_subject_line
# 6379   i2 Board of Directors Meeting
# 12129               meeting with you
# 10080     missing computer equipment
# 2534                             qbr
# 11347    products trading guidelines
# 4786              Credit Attachments
# 9099                    Pioneer gisb
# 3780                      doubletree
# 11931    Energy Derivatives Seminars
# 2626                     Enron Corp.

# %%
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)


# Evaluate the generated subject lines
def evaluate_metrics(true_subject, generated_subject):
    # Tokenize the input for METEOR
    true_subject_tokens = nltk.word_tokenize(true_subject)
    generated_subject_tokens = nltk.word_tokenize(generated_subject)

    # ROUGE-L
    rougeL = scorer.score(true_subject, generated_subject)['rougeL'].fmeasure

    # METEOR
    meteor = meteor_score([true_subject_tokens], generated_subject_tokens) # Pass tokenized input

    # SACREBLEU - Use import sacrebleu directly
    sacre_bleu_score = sacrebleu.corpus_bleu([generated_subject], [[true_subject]]).score

    return rougeL, meteor, sacre_bleu_score # Return the score, not the module

test_df['rougeL'], test_df['meteor'], test_df['sacrebleu'] = zip(*test_df.apply(
    lambda row: evaluate_metrics(row['subject'], row['generated_subject_line']), axis=1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'generated_subject_line'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-c0bd341a4e96> in <cell line: 21>()
#      19     return rougeL, meteor, sacre_bleu_score # Return the score, not the module
#      20
# ---> 21 test_df['rougeL'], test_df['meteor'], test_df['sacrebleu'] = zip(*test_df.apply(
#      22     lambda row: evaluate_metrics(row['subject'], row['generated_subject_line']), axis=1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9421             kwargs=kwargs,
#    9422         )
# -> 9423         return op.apply().__finalize__(self, method="apply")
#    9424
#    9425     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     676             return self.apply_raw()
#     677
# --> 678         return self.apply_standard()
#     679
#     680     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     796
#     797     def apply_standard(self):
# --> 798         results, res_index = self.apply_series_generator()
#     799
#     800         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     812             for i, v in enumerate(series_gen):
#     813                 # ignore SettingWithCopy here in case the user mutates
# --> 814                 results[i] = self.f(v)
#     815                 if isinstance(results[i], ABCSeries):
#     816                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-46-c0bd341a4e96> in <lambda>(row)
#      20
#      21 test_df['rougeL'], test_df['meteor'], test_df['sacrebleu'] = zip(*test_df.apply(
# ---> 22     lambda row: evaluate_metrics(row['subject'], row['generated_subject_line']), axis=1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'generated_subject_line'

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch"
)

# %%
start_prompt = 'Generate the subject line for the following email.\n\nEmail:'
end_prompt = '\nSubject:\n'
start_prompt + email + end_prompt
print(start_prompt)
print(email)
print(end_prompt)
# Out:
# Generate the subject line for the following email.
#
# Email:
# many of you have asked about procedures to evaluate employee performance. we are finalizing a performance process designed to track and provide feedback on individual accomplishments for the benefit of each employee the company and the unsecured creditors committee. a very simple and straightforward online performance assessment system pas will allow us to automate parts of the process. pas will open next week on monday may 13 and remain open through friday may 24 2002. as an employee of a debtor company you should access the system and complete your self assessment by friday may 17 2002. your supervisor will review and approve submitted accomplishments and schedule a facetoface meeting to discuss your contributions offer feedback set priorities for the upcoming period discuss challenges and potential development opportunities and if applicable confirm your quarterly retention payout and project a target for the upcoming quarter. pas will be accessible through the hr global launch zone. well send a reminder with more details next week. in the meantime if you have questions about the process you can contact your hr representative.
#
# Subject:

# %%
# Tokenization for FLAN-T5 model
def flan_t5_base_tokenize_function(example):
    start_prompt = 'Generate the subject line for the following email.\n\nEmail:'
    end_prompt = '\nSubject:\n'
    prompt = [start_prompt + email + end_prompt for email in example["body"]]
    example['input_ids'] = flan_t5_base_tokenizer(prompt, padding="max_length", truncation=True, return_tensors="pt").input_ids
    example['labels'] = flan_t5_base_tokenizer(example["subject"], padding="max_length", truncation=True, return_tensors="pt").input_ids

    return example

# The dataset actually contains 3 diff splits: train, validation, test.
# The tokenize_function code is handling all data across all splits in batches.
tokenized_train_datasets = train_dataset.map(flan_t5_base_tokenize_function, batched=True)
tokenized_test_datasets = test_dataset.map(flan_t5_base_tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/2310 [00:00<?, ? examples/s]
# Map:   0%|          | 0/462 [00:00<?, ? examples/s]

# %%
# tokenized_train_datasets = tokenized_train_datasets.filter(lambda example, index: index % 100 == 0, with_indices=True)
# tokenized_test_datasets = tokenized_test_datasets.filter(lambda example, index: index % 100 == 0, with_indices=True)

# %%
tokenized_train_datasets, tokenized_test_datasets
# Out:
# (Dataset({
#      features: ['source', 'body', 'subject', 'ann0', 'ann1', 'ann2', 'body_wcount', 'subj_wcount', 'cleaned_emails', '__index_level_0__', 'input_ids', 'labels'],
#      num_rows: 2310
#  }),
#  Dataset({
#      features: ['source', 'body', 'subject', 'ann0', 'ann1', 'ann2', 'body_wcount', 'subj_wcount', 'cleaned_emails', '__index_level_0__', 'input_ids', 'labels'],
#      num_rows: 462
#  }))

# %% [markdown]
# **FLAN-T5 BASE - Fine-Tune the Model with the Preprocessed Tokenised Dataset utiliing the built-in Hugging Face Trainer class. Then compare it with reference to the original model.**
#
# flan_t5_base_original_model = AutoModelForSeq2SeqLM.from_pretrained('google/flan-t5-base', torch_dtype=torch.bfloat16)
# flan_t5_base_tokenizer = AutoTokenizer.from_pretrained('google/flan-t5-base')

# %%
tokenizer = T5Tokenizer.from_pretrained('google/flan-t5-base')

def tokenize_function(examples):
    start_prompt = 'Generate the subject line for the following email.\n\nEmail:'
    end_prompt = '\nSubject:\n'
    inputs = [start_prompt + email + end_prompt for email in examples['email_body']]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding='max_length')

    labels = tokenizer(examples['subject'], max_length=50, truncation=True, padding='max_length')
    model_inputs['labels'] = labels['input_ids']
    return model_inputs

tokenized_dataset = dataset.map(tokenize_function, batched=True, remove_columns=dataset.column_names)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-4d78fcbec856> in <cell line: 13>()
#      11     return model_inputs
#      12
# ---> 13 tokenized_dataset = dataset.map(tokenize_function, batched=True, remove_columns=dataset.column_names)
#
# NameError: name 'dataset' is not defined

# %%
# # Tokenization
# def preprocess_data(examples):
#     inputs = ["generate subject line: " + email for email in examples['cleaned_emails']]
#     model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")

#     with tokenizer.as_target_tokenizer():
#         labels = tokenizer(examples['subject'], max_length=128, truncation=True, padding="max_length")

#     model_inputs["labels"] = labels["input_ids"]
#     return model_inputs

# train_dataset = train_dataset.map(preprocess_data, batched=True)
# test_dataset = test_dataset.map(preprocess_data, batched=True)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
)

# Define Trainer
trainer = Trainer(
    model=flan_t5_base_original_model ,
    args=training_args,
    train_dataset=tokenized_train_datasets,
    eval_dataset=tokenized_test_datasets,
)

# Train the model
trainer.train()

# %% [markdown]
# FLAN-T5 SMALL - Fine-Tune the Model with the Preprocessed Tokenised Dataset utiliing the built-in Hugging Face Trainer class. Then compare it with reference to the original model.
#
# flan_t5_small_model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small", torch_dtype=torch.bfloat16)
# flan_t5_small_tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")

# %%
# Tokenization for FLAN-T5 SMALL model
def flan_t5_small_tokenize_function(example):
    start_prompt = 'Generate the subject line for the following email.\n\nEmail:'
    end_prompt = '\nSubject:\n'
    prompt = [start_prompt + email + end_prompt for email in example["cleaned_emails"]]
    example['input_ids'] = flan_t5_small_tokenizer(prompt, padding="max_length", truncation=True, return_tensors="pt").input_ids
    example['labels'] = flan_t5_small_tokenizer(example["subject"], padding="max_length", truncation=True, return_tensors="pt").input_ids

    return example

# The dataset actually contains 3 diff splits: train, validation, test.
# The tokenize_function code is handling all data across all splits in batches.
tokenized_train_datasets = train_dataset.map(flan_t5_small_tokenize_function, batched=True)
tokenized_test_datasets = test_dataset.map(flan_t5_small_tokenize_function, batched=True)

# %%
# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
)

# Define Trainer
trainer = Trainer(
    model=flan_t5_small_model,
    args=training_args,
    train_dataset=tokenized_train_datasets,
    eval_dataset=tokenized_test_datasets,
)

# Train the model
trainer.train()

# %%
# Save the model checkpoint
flan_t5_small_model.save_pretrained('./results/Flan_T5_small_model')
flan_t5_small_tokenizer.save_pretrained('./results/Flan_T5_small_model')

# Define and save the generation configuration
generation_config = GenerationConfig(
    early_stopping=True,
    num_beams=4,
    no_repeat_ngram_size=3,
    forced_bos_token_id=0,
    forced_eos_token_id=2
)

generation_config.save_pretrained('./results/Flan_T5_small_model')

# %%
AutoModelForSeq2SeqLM
AutoTokenizer

# %%
# Load the trained Flan T5 Small fine tuned model
flan_T5_small_model_directory = '/content/results/Flan_T5_small_model'
flan_T5_small_tokenizer = AutoTokenizer.from_pretrained(flan_T5_small_model_directory)
flan_T5_small_model_finetuned = AutoModelForSeq2SeqLM.from_pretrained(flan_T5_small_model_directory)

# %%
emails_for_score = tokenized_test_datasets[0:10]['cleaned_emails']
original_subjects = tokenized_test_datasets[0:10]['subject']

# %%
flan_T5small_subjects = []
finetuned_flan_T5small_subjects = []

for _, cleaned_emails in enumerate(emails_for_score):
    prompt = f"""
    Generate the subject line for the following email.

    Email:
    {email}

    Subject:
    """
    # Tokenize the input and move to the same device as the model
    inputs = flan_t5_small_tokenizer(prompt, return_tensors='pt').to(flan_T5_small_model_finetuned.device) # Move inputs to the same device as the fine-tuned model

    # Add the decoder_start_token_id to the generation configuration
    generation_config = GenerationConfig(max_new_tokens=200,
        decoder_start_token_id=flan_T5_small_tokenizer.bos_token_id if flan_T5_small_tokenizer.bos_token_id is not None else flan_T5_small_tokenizer.eos_token_id
    )



    # Generate subject using the original model
    # Make sure flan_t5_small_model is on the same device as flan_T5_small_model_finetuned
    flan_t5_small_model = flan_t5_small_model.to(flan_T5_small_model_finetuned.device)
    original_model_outputs = flan_t5_small_model.generate(**inputs, generation_config=generation_config)
    original_model_subject_output = flan_t5_small_tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)
    flan_T5small_subjects.append(original_model_subject_output)

    # Generate subject using the finetuned model
    trained_flan_t5_outputs = flan_T5_small_model_finetuned.generate(**inputs, generation_config=generation_config)
    instruct_model_text_output = flan_T5_small_tokenizer.decode(trained_flan_t5_outputs[0], skip_special_tokens=True)
    finetuned_flan_T5small_subjects.append(instruct_model_text_output)

zipped_summaries = list(zip(original_subjects, flan_T5small_subjects, finetuned_flan_T5small_subjects))

Flan_T5_Small_Subjects_df = pd.DataFrame(zipped_summaries, columns = ['Original_subjects', 'Flan_T5s_subjects', 'Finetuned_Flan_T5s_subjects'])
Flan_T5_Small_Subjects_df

# %%
# from transformers import T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments
# from datasets import Dataset


# # Initialize tokenizer and model
# tokenizer = T5Tokenizer.from_pretrained('t5-small')
# T5_model = T5ForConditionalGeneration.from_pretrained('t5-small')

# %%
def tokenize_function(example):
    start_prompt = 'Generate the subject line for the following email.\n\n'
    end_prompt = '\n\Subject: '
    prompt = [start_prompt + email + end_prompt for email in example["cleaned_emails"]]
    # Tokenize the input_ids - do not flatten
    example['input_ids'] = [tokenizer(p, padding="max_length", truncation=True, return_tensors="pt").input_ids[0] for p in prompt]
    # Tokenize the labels - do not flatten
    example['labels'] = [tokenizer(s, padding="max_length", truncation=True, return_tensors="pt").input_ids[0] for s in example["subject"]]

    return example

# %%
# output_dir = f'./email-Subject-training-{str(int(time.time()))}'

# # Define training arguments
# training_args = TrainingArguments(
#     output_dir=output_dir,
#     learning_rate=1e-5,
#     num_train_epochs=3,
#     weight_decay=0.01,
#     logging_steps=30,
#     evaluation_strategy='epoch',
#     per_device_train_batch_size=4,  # Reduced batch size
#     # max_steps=1
# )

# # training_args = TrainingArguments(
# #     output_dir='./results',
# #     evaluation_strategy='epoch',
# #     learning_rate=1e-5,
# #     per_device_train_batch_size=4,
# #     per_device_eval_batch_size=4,
# #     num_train_epochs=3,
# #     weight_decay=0.01,
# # )

# trainer = Trainer(
#     model=flan_t5_base_original_model,
#     args=training_args,
#     train_dataset=tokenized_train_datasets,
#     eval_dataset=tokenized_test_datasets
# )

# trainer.train()

# %%
# # Generate subject lines for the test set
# def generate_subject_line(email_body):
#     inputs = tokenizer("generate subject line: " + email_body, return_tensors="pt", max_length=512, truncation=True)
#     # Move inputs to the same device as the model
#     inputs = {k: v.to(model.device) for k, v in inputs.items()}
#     outputs = model.generate(inputs.input_ids, max_length=128, num_beams=4, early_stopping=True)
#     return tokenizer.decode(outputs[0], skip_special_tokens=True)

# test_df['generated_subject_line'] = test_df['cleaned_emails'].apply(generate_subject_line)

# Generate subject lines for the test set
def generate_subject_line(email_body):
    inputs = tokenizer("generate subject line: " + email_body, return_tensors="pt", max_length=512, truncation=True)
    # Move inputs to the same device as the model
    inputs = {k: v.to(model.device) for k, v in inputs.items()}
    # Access input_ids as a key in the dictionary
    outputs = model.generate(inputs['input_ids'], max_length=128, num_beams=4, early_stopping=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

test_df['generated_subject_line'] = test_df['cleaned_emails'].apply(generate_subject_line)

# %% [markdown]
# # **t5-small Evaluation**

# %%
# !pip install nltk
import nltk
from rouge_score import rouge_scorer
import sacrebleu
from nltk.translate.meteor_score import meteor_score
# Initialize ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

# %%
# Download the 'punkt' resource
nltk.download('punkt')
nltk.download('wordnet') # Download WordNet

from rouge_score import rouge_scorer
import sacrebleu
from nltk.translate.meteor_score import meteor_score
# Initialize ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)


# Evaluate the generated subject lines
def evaluate_metrics(true_subject, generated_subject):
    # Tokenize the input for METEOR
    true_subject_tokens = nltk.word_tokenize(true_subject)
    generated_subject_tokens = nltk.word_tokenize(generated_subject)

    # ROUGE-L
    rougeL = scorer.score(true_subject, generated_subject)['rougeL'].fmeasure

    # METEOR
    meteor = meteor_score([true_subject_tokens], generated_subject_tokens) # Pass tokenized input

    # SACREBLEU - Use import sacrebleu directly
    sacre_bleu_score = sacrebleu.corpus_bleu([generated_subject], [[true_subject]]).score

    return rougeL, meteor, sacre_bleu_score # Return the score, not the module

test_df['rougeL'], test_df['meteor'], test_df['sacrebleu'] = zip(*test_df.apply(
    lambda row: evaluate_metrics(row['subject'], row['generated_subject_line']), axis=1))

# Calculate average scores
average_rougeL = test_df['rougeL'].mean()
average_meteor = test_df['meteor'].mean()
average_sacrebleu = test_df['sacrebleu'].mean() # Now you should be able to calculate the mean

print(f'Average ROUGE-L: {average_rougeL:.4f}')
print(f'Average METEOR: {average_meteor:.4f}')
print(f'Average SACREBLEU: {average_sacrebleu:.4f}')

# %% [markdown]
# # **Pretrained('facebook/bart-base')**

# %%
from transformers import BartTokenizer, BartForConditionalGeneration, Trainer, TrainingArguments
from datasets import Dataset

# %%
# # Convert DataFrame to Dataset
# train_dataset = Dataset.from_pandas(train_df)
# test_dataset = Dataset.from_pandas(test_df)

# Initialize tokenizer and model
facebook_bart_tokenizer = BartTokenizer.from_pretrained('facebook/bart-base')
facebook_bart_base_model = BartForConditionalGeneration.from_pretrained('facebook/bart-base')

# %%
print("For Model : facebook_bart_base_model \n",print_number_of_trainable_model_parameters(facebook_bart_base_model))

# %%
prompt = f"""
Generate the subject line for the following email.

Email:
{email}

Subject:
"""

inputs = facebook_bart_tokenizer(prompt, return_tensors='pt')

# Move input tensors to the same device as the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
inputs = {k: v.to(facebook_bart_base_model.device) for k, v in inputs.items()}

outputs = facebook_bart_base_model.generate(inputs['input_ids'], max_length=128, num_beams=4, early_stopping=True)

dash_line = '-'.join('' for x in range(100))
print(dash_line)
print(f'INPUT PROMPT:\n{prompt}')
print(dash_line)
print(f'BASELINE ORIGINAL HUMAN ANNOTED SUBJECT LINE :\n{subject}\n')
print(dash_line)
print(f'FB BART MODEL GENERATION - ZERO SHOT SUBJECT LINE:\n{output}')

# %%
# Tokenization
def Tokenization_preprocess_data(examples):
    inputs = [prompt + email for email in examples['cleaned_emails']]
    model_inputs = facebook_bart_tokenizer(inputs, max_length=512, truncation=True, padding="max_length")

    # Use facebook_bart_tokenizer as the target tokenizer
    with facebook_bart_tokenizer.as_target_tokenizer():
        labels = facebook_bart_tokenizer(examples['subject'], max_length=128, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

train_dataset = train_dataset.map(Tokenization_preprocess_data, batched=True)
test_dataset = test_dataset.map(Tokenization_preprocess_data, batched=True)

# # Define training arguments
# training_args = TrainingArguments(
#     output_dir='./results',
#     evaluation_strategy='epoch',
#     learning_rate=2e-5,
#     per_device_train_batch_size=4,
#     per_device_eval_batch_size=4,
#     num_train_epochs=3,
#     weight_decay=0.01,
# )


training_args = TrainingArguments(
    output_dir='./results',        # Directory to save the model checkpoints
    evaluation_strategy='steps',
    save_steps=500,               # Save checkpoint every 1000 steps
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=200,
)

# Define Trainer
facebook_bart_base_model_trainer = Trainer(
    model=facebook_bart_base_model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
)

# Train the model
facebook_bart_base_model_trainer.train()

# %%
# Save the final model checkpoint
facebook_bart_base_model.save_pretrained('./results/FB_Bart_model')
facebook_bart_tokenizer.save_pretrained('./results/FB_Bart_model')

# Define and save the generation configuration
generation_config = GenerationConfig(
    early_stopping=True,
    num_beams=4,
    no_repeat_ngram_size=3,
    forced_bos_token_id=0,
    forced_eos_token_id=2
)

generation_config.save_pretrained('./results/FB_Bart_model')

# %%
cd /content

# %%
# Define paths
logs_folder = '/content/logs'  # Adjust to your source folder
logs_git_folder = './content/qM-AI-L/email-subject/model-tuning/logs'  # Adjust to your repository folder

# Copy the folder
shutil.copytree(logs_folder, logs_git_folder)

# %%
# Define paths
results_folder = '/content/results'  # Adjust to your source folder
results_git_folder = './content/qM-AI-L/email-subject/model-tuning/results'  # Adjust to your repository folder

# Copy the folder
shutil.copytree(results_folder, results_git_folder)

# %%
# Change directory to the cloned repository
os.chdir('./content/qM-AI-L')  # Adjust to your repository folder

# Configure Git (only needed once)
# !git config --global user.email "mlreddy3082@gmail.com"
# !git config --global user.name "Mlr9459"

# Add, commit, and push changes
# !git add /content/qM-AI-L/email-subject/
# !git commit -m "Add training outputs: model checkpoints, tokenizer, and generation configuration"
# !git push origin master

# %% [markdown]
# **Evaluate the Model Quantitatively (with ROUGE Metric)
# The ROUGE metric) helps quantify the validity of summarizations produced by models. It compares summarizations to a "baseline" summary which is usually created by a human. While not perfect, it does indicate the overall increase in summarization effectiveness that we have accomplished by fine-tuning.**

# %%
tokenized_train_datasets, tokenized_test_datasets

# %%
tokenized_train_datasets[0:10]['cleaned_emails']

# %%
emails_for_score = tokenized_test_datasets[0:10]['cleaned_emails']
human_annoted_subjects = tokenized_test_datasets[0:10]['subject']

# %%
facebook_bart_tokenizer = BartTokenizer.from_pretrained('facebook/bart-base')
facebook_bart_base_model = BartForConditionalGeneration.from_pretrained('facebook/bart-base')

# %%
model_directory = '/content/results/FB_Bart_model'
facebook_bart_tokenizer_trained = BartTokenizer.from_pretrained(model_directory)
facebook_bart_base_model_trained = BartForConditionalGeneration.from_pretrained(model_directory)

# %%
facebook_bart_subjects = []
trained_facebook_bart_subjects = []

for _, email in enumerate(emails_for_score):
    prompt = f"""
    Generate the subject line for the following email.

    Email:
    {email}

    Subject:
    """
    # Tokenize the input and move to the same device as the model
    inputs = facebook_bart_tokenizer(prompt, return_tensors='pt').to(facebook_bart_base_model.device)

    # Add the decoder_start_token_id to the generation configuration
    generation_config = GenerationConfig(
    max_new_tokens=200,
    decoder_start_token_id=facebook_bart_tokenizer.bos_token_id  # Add this line
    )



    # Generate subject using the original model
    original_model_outputs = facebook_bart_base_model.generate(**inputs, generation_config=generation_config)
    original_model_subject_output = facebook_bart_tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)
    facebook_bart_subjects.append(original_model_subject_output)

    trained_facebook_bart_outputs = facebook_bart_base_model_trained.generate(**inputs, generation_config=generation_config)
    instruct_model_text_output = facebook_bart_tokenizer_trained.decode(trained_facebook_bart_outputs[0], skip_special_tokens=True)
    trained_facebook_bart_subjects.append(instruct_model_text_output)

zipped_summaries = list(zip(human_annoted_subjects, facebook_bart_subjects, trained_facebook_bart_subjects))

df = pd.DataFrame(zipped_summaries, columns = ['human_annoted_subjects', 'facebook_bart_subjects', 'trained_facebook_bart_subjects'])
df

# %%
# !pip install rouge-score
from rouge_score import rouge_scorer
from rouge_score.scoring import BootstrapAggregator

# %%
# Calculate ROUGE scores for each pair of prediction and reference
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
aggregator = BootstrapAggregator() # Initialize aggregator

for prediction, reference in zip(facebook_bart_subjects, human_annoted_subjects[0:len(facebook_bart_subjects)]):
    score = scorer.score(reference, prediction)
    aggregator.add_scores(score) # Add scores to aggregator

# Aggregate the scores
original_model_results = aggregator.aggregate()

print(original_model_results)

# %%
original_model_results = rouge.compute(
    predictions=facebook_bart_subjects,
    references=human_annoted_subjects[0:len(facebook_bart_subjects)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=trained_facebook_bart_subjects,
    references=human_annoted_subjects[0:len(trained_facebook_bart_subjects)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)

# %%
# Save the model locally
model_save_path = "./facebook_bart_base"
facebook_bart_base_model.save_pretrained(model_save_path)
tokenizer.save_pretrained(model_save_path)

print(f"Model and tokenizer saved to {model_save_path}")

# %%
# Generate subject lines for the test set
def generate_subject_line(email_body):
    inputs = tokenizer("generate subject line: " + email_body, return_tensors="pt", max_length=512, truncation=True)
    # Move inputs to the GPU if available
    inputs = {k: v.to(facebook_bart_base_model.device) for k, v in inputs.items()}
    # Access input_ids from the dictionary
    outputs = facebook_bart_base_model.generate(inputs['input_ids'], max_length=128, num_beams=4, early_stopping=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

test_df['generated_subject_line'] = test_df['body'].apply(generate_subject_line)

# %%
test_df

# %%
import nltk
from rouge_score import rouge_scorer
import sacrebleu
from nltk.translate.meteor_score import meteor_score

# %%
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)


# Evaluate the generated subject lines
def evaluate_metrics(true_subject, generated_subject):
    # Tokenize the input for METEOR
    true_subject_tokens = nltk.word_tokenize(true_subject)
    generated_subject_tokens = nltk.word_tokenize(generated_subject)

    # ROUGE-L
    rougeL = scorer.score(true_subject, generated_subject)['rougeL'].fmeasure

    # METEOR
    meteor = meteor_score([true_subject_tokens], generated_subject_tokens) # Pass tokenized input

    # SACREBLEU - Use import sacrebleu directly
    sacre_bleu_score = sacrebleu.corpus_bleu([generated_subject], [[true_subject]]).score

    return rougeL, meteor, sacre_bleu_score # Return the score, not the module

test_df['rougeL'], test_df['meteor'], test_df['sacrebleu'] = zip(*test_df.apply(
    lambda row: evaluate_metrics(row['subject'], row['generated_subject_line']), axis=1))

# %%
# Calculate average scores
average_rougeL = test_df['rougeL'].mean()
average_meteor = test_df['meteor'].mean()
average_sacrebleu = test_df['sacrebleu'].mean() # Now you should be able to calculate the mean

print(f'Average facebook_bart_base_model ROUGE-L: {average_rougeL:.4f}')
print(f'Average facebook_bart_base_model METEOR: {average_meteor:.4f}')
print(f'Average facebook_bart_base_model SACREBLEU: {average_sacrebleu:.4f}')

# %%
import shutil
from google.colab import files

# Replace 'directory_name' with the name of your directory
shutil.make_archive('/content/facebook_bart_base_model', 'zip', 'facebook_bart_base_model')

# %%
# files.download('facebook_bart_base_model.zip')

# %% [markdown]
# # **t5-base**

# %%
# Define tokenizer and model t5-base
tokenizer = T5Tokenizer.from_pretrained("t5-base")
model = T5ForConditionalGeneration.from_pretrained("t5-base")

# %%
dataset = Dataset.from_pandas(pivot_df)

# %%
dataset

# %%
def preprocess_function(pivot_df):
    inputs = pivot_df['cleaned_emails']
    targets = pivot_df['subject']
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=128, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_dataset = dataset.map(preprocess_function, batched=True)

# %%
import shutil
from google.colab import files

# Replace 'directory_name' with the name of your directory
# shutil.make_archive('/content/fine_tuned_t5', 'zip', 'fine_tuned_t5')

# Download the zipped directory

# %%
shutil.make_archive('/content/results', 'zip', 'FB_Bart_model_results')
shutil.make_archive('/content/logs', 'zip', 'FB_Bart_model_logs')

# %%
# files.download('fine_tuned_t5.zip')

# %%
tokenized_dataset

# %%
# tokenized_dataset['attention_mask']
# tokenized_dataset['input_ids']

# %%
# Split the dataset into train and test sets
train_test_split = tokenized_dataset.train_test_split(test_size=0.2)
train_dataset = train_test_split['train']
eval_dataset = train_test_split['test']

# Data collator for padding
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=3,
    # predict_with_generate=True,
    logging_dir="./logs",
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# Train the model
trainer.train()

# %%
model.save_pretrained('fine_tuned_t5')
tokenizer.save_pretrained('fine_tuned_t5')

# %%
# Checking if GPU is available
if torch.cuda.is_available():
    print("GPU is available. \nUsing GPU")
    device = torch.device('cuda')
else:
    print("GPU is not available. \nUsing CPU")
    device = torch.device('cpu')

# %%
def generate_summary(text):
    inputs = tokenizer.encode_plus(text, return_tensors='pt', max_length=512, truncation=True)
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)

    summary_ids = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=150, num_beams=2, repetition_penalty=2.5, length_penalty=1.0, early_stopping=True)

    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %%
# Example inference
example_text = pivot_df['body'][3]
print("Email Body:", example_text)
print("\n\n Generated Subject:", generate_summary(example_text))
print("\n\n Actual Subject:", pivot_df['subject'][3])

# %%
from rouge_score import rouge_scorer
import sacrebleu
from nltk.translate.meteor_score import meteor_score

# Initialize ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

# Evaluate the generated subject lines
def evaluate_metrics(true_subject, generated_subject):
    # ROUGE-L
    rougeL = scorer.score(true_subject, generated_subject)['rougeL'].fmeasure

    # METEOR
    meteor = meteor_score([true_subject], generated_subject)

    # SACREBLEU
    sacre_bleu = sacrebleu.corpus_bleu([generated_subject], [[true_subject]]).score

    return rougeL, meteor, sacre_bleu

test_df['rougeL'], test_df['meteor'], test_df['sacrebleu'] = zip(*test_df.apply(
    lambda row: evaluate_metrics(row['subject_line'], row['generated_subject_line']), axis=1))

# Calculate average scores
average_rougeL = test_df['rougeL'].mean()
average_meteor = test_df['meteor'].mean()
average_sacrebleu = test_df['sacrebleu'].mean()

print(f'Average ROUGE-L: {average_rougeL:.4f}')
print(f'Average METEOR: {average_meteor:.4f}')
print(f'Average SACREBLEU: {average_sacrebleu:.4f}')

# %%
import re

def extract_sentences(text):
  """
  This function extracts sentences from text without introducing control characters.

  Args:
      text (str): The text to be processed.

  Returns:
      list: A list of extracted sentences.
  """
  # Split text based on sentence boundaries (adjust pattern as needed)
  sentences = re.split(r"(?<!\w)\.(?!\w)", text)

  # Remove empty elements and leading/trailing whitespace
  sentences = [sentence.strip() for sentence in sentences if sentence.strip()]

  return sentences

# Example usage
text = "This is an example text. It contains multiple sentences.  \nThere are also newlines and extra spaces."
extracted_sentences = extract_sentences(pivot_df['body'][0])
print(extracted_sentences)

# %%
pivot_df['body'][0]

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
summary = summarizer(pivot_df['body'][0], max_length=15, min_length=2, do_sample=False)
print(summary[0]['summary_text'])

# %%
pivot_df['body'][0]

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
model = AutoModelForSeq2SeqLM.from_pretrained("Chirayu/subject-generator-t5-base")
tokenizer = AutoTokenizer.from_pretrained("Chirayu/subject-generator-t5-base")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

def get_subject(content, num_beams=5,max_length=512, repetition_penalty=2.5, length_penalty=1, early_stopping=True,top_p=.95, top_k=50, num_return_sequences=3):

  text =  "title: " + content + " </s>"

  input_ids = tokenizer.encode(
    text, return_tensors="pt", add_special_tokens=True
  )

  input_ids = input_ids.to(device)
  generated_ids = model.generate(
      input_ids=input_ids,

      num_beams=num_beams,
      max_length=max_length,
      repetition_penalty=repetition_penalty,
      length_penalty=length_penalty,
      early_stopping=early_stopping,
      top_p=top_p,
      top_k=top_k,
      num_return_sequences=num_return_sequences,
  )
  subjects = [tokenizer.decode(generated_id,skip_special_tokens=True,clean_up_tokenization_spaces=True,) for generated_id in generated_ids]
  return subjects

# %%
x = get_subject(pivot_df['body'][0])
x

# %%
pivot_df['body'][0]

# %%
pivot_df['body'][1]

# %%
import textwrap

# %%
def text_summarizer(email_text):

    model_name = "facebook/bart-large-cnn"
    model = BartForConditionalGeneration.from_pretrained(model_name)
    tokenizer = BartTokenizer.from_pretrained(model_name)

    inputs = tokenizer.encode("summarize: " + email_text, return_tensors="pt", max_length=1024, truncation=True)
    summary_ids = model.generate(inputs, max_length=100, min_length=50, length_penalty=2.0, num_beams=4, early_stopping=True)

    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    formatted_summary = "\n".join(textwrap.wrap(summary, width=80))
    return formatted_summary

summary = text_summarizer(pivot_df['body'][0])
summary

# %%
def extract_sentences(text):
    """
    Extract sentences from the text and remove newline characters.

    Parameters:
    text (str): The text to process.

    Returns:
    list: A list of sentences without newline characters.
    """
    # Replace newline characters with spaces
    text = text.replace('\n', '')
    text = text.replace('!', '.').replace('?', '.').replace(';', '.')

    # Tokenize the text into sentences
    sentences = sent_tokenize(text)

    return sentences

# Example usage
sample_text = "Hello, world!\nThis is a test.\nLet's replace, commas, and newlines."
sentences = extract_sentences(sample_text)
for sentence in sentences:
    print(sentence)

# %%
summary = text_summarizer(pivot_df['body'][0])
summary

# %%
pivot_df['body'][0]

# %%
email_len = [len(pivot_df['dialogue'].split()) for x in samsum['train']]
sub_len = [len(pivot_df['summary'].split()) for x in samsum['train']]

dialogue_len = [len(x['dialogue'].split()) for x in samsum['train']]
summary_len = [len(x['summary'].split()) for x in samsum['train']]

# %%
describe_df(pivot_df)

# %%
nan_rows

# %%
from langchain.preprocessing import Tokenizer, Lowercaser, PunctuationRemover, StopwordRemover
from langchain.stemming import Stemmer
from langchain import Pipeline

# %%
len(email_docs)*3

# %%
emails_df['content'][0]

# %%
emails_df['source'][0]

# %%
extract_file_name(emails_df['source'][0])
