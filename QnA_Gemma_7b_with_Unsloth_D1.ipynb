# %% [markdown]
# <a href="https://colab.research.google.com/github/nutworker/qM-AI-L/blob/main/QnA_Gemma_7b_with_Unsloth_D1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
repository_url = 'https://github.com/nutworker/qM-AI-L'
# !git clone {repository_url}
# Out:
# Cloning into 'qM-AI-L'...
# remote: Enumerating objects: 495, done.
# remote: Counting objects: 100% (333/333), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 495 (delta 198), reused 190 (delta 133), pack-reused 162 (from 1)
# Receiving objects: 100% (495/495), 14.19 MiB | 12.53 MiB/s, done.
# Resolving deltas: 100% (258/258), done.

# %%
# !pip install "unsloth[colab] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-cn1_b1mj/unsloth_3fbef93d68774c839a5f9d3801b7afbd
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-cn1_b1mj/unsloth_3fbef93d68774c839a5f9d3801b7afbd
#   Resolved https://github.com/unslothai/unsloth.git to commit 6c534341bb229b136f9504443f0161645d2070c5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting bitsandbytes>=0.43.3 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.4.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.26.4)
# Collecting xformers@ https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl (211.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (24.1)
# Collecting tyro (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading tyro-0.8.10-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: transformers>=4.43.2 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.44.2)
# Collecting datasets>=2.16.0 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting sentencepiece>=0.2.0 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.44.0)
# Requirement already satisfied: accelerate>=0.26.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.33.0)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading trl-0.10.1-py3-none-any.whl.metadata (12 kB)
# Collecting peft!=0.11.0,>=0.7.1 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.24.6)
# Collecting hf-transfer (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (6.0.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.15.4)
# Collecting pyarrow>=15.0.0 (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.32.3)
# Collecting xxhash (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.10.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.43.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.43.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.19.1)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (13.8.0)
# Collecting shtab>=1.5.6 (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting torch (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading torch-2.1.0-cp310-cp310-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.1.0 (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Downloading bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl (137.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 7.6 MB/s eta 0:00:00
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 28.9 MB/s eta 0:00:00
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 23.7 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.9 MB/s eta 0:00:00
# Downloading trl-0.10.1-py3-none-any.whl (280 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.1/280.1 kB 14.5 MB/s eta 0:00:00
# Downloading tyro-0.8.10-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 8.7 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 56.1 MB/s eta 0:00:00
# Downloading torch-2.1.0-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 868.9 kB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 39.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 42.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 37.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 9.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.1 MB/s eta 0:00:00
# Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 7.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 14.7 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 62.7 MB/s eta 0:00:00
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.8-py3-none-any.whl size=152932 sha256=82c66e74a3ecd92615ef58d8321ffb0660e4eed4fb48e52f53049c7db78b0da1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-78cnt7ci/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: sentencepiece, xxhash, unsloth, triton, shtab, pyarrow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, hf-transfer, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, tyro, nvidia-cusolver-cu12, torch, datasets, xformers, bitsandbytes, trl, peft
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.99
#     Uninstalling sentencepiece-0.1.99:
#       Successfully uninstalled sentencepiece-0.1.99
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.22.3
#     Uninstalling nvidia-nccl-cu12-2.22.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.22.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0+cu121
#     Uninstalling torch-2.4.0+cu121:
#       Successfully uninstalled torch-2.4.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# torchaudio 2.4.0+cu121 requires torch==2.4.0, but you have torch 2.1.0 which is incompatible.
# torchvision 0.19.0+cu121 requires torch==2.4.0, but you have torch 2.1.0 which is incompatible.
# Successfully installed bitsandbytes-0.43.3 datasets-2.21.0 dill-0.3.8 hf-transfer-0.1.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 peft-0.12.0 pyarrow-17.0.0 sentencepiece-0.2.0 shtab-1.7.1 torch-2.1.0 triton-2.1.0 trl-0.10.1 tyro-0.8.10 unsloth-2024.8 xformers-0.0.22.post7 xxhash-3.5.0

# %% [markdown]
# # **Setting Up the Environment**

# %%
# !pip install rouge_score
from rouge_score import rouge_scorer
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.5)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=f493f54933d5608e6b63949d311eaec871c1388be18e4eb984341e9cb65bb126
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# Importing Libraries

import os
import re
import pandas as pd # Data Handling
import torch
import tensorflow as tf
import numpy as np
import time
from google.colab import files
import shutil

# import seaborn as sns

# from datasets import load_metric
# from datasets import Dataset

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Import the FastLanguageModel class from the unsloth library.
from unsloth import FastLanguageModel
# Import the torch library.

# Set the maximum sequence length to 8192 tokens.
max_seq_length = 8192

# Set the data type to None for automatic detection.
dtype = None

# Set the load_in_4bit flag to True to load the model weights in 4-bit precision.
load_in_4bit = True
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %% [markdown]
# # **Downloading 4-bit Quantized Model and Adding LoRA Adapters**

# %%
# Load the pre-trained model from the 'unsloth/gemma-7b-bnb-4bit' repository.
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gemma-7b-bnb-4bit",

    # Set the maximum sequence length to the value defined earlier.
    max_seq_length = max_seq_length,

    # Set the data type to the value defined earlier.
    dtype = dtype,

    # Set the load_in_4bit flag to the value defined earlier.
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.8: Fast Gemma patching. Transformers = 4.44.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.1.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.22.post7. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.57G [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# generation_config.json:   0%|          | 0.00/154 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/40.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]

# %% [markdown]
# # **Dataset-1 :Preparing the Dataset for Fine-tuning**

# %%
D1_train_path = '/content/qM-AI-L/QA-Chatbot/Dataset-1/aiml-qa-train.xlsx'
D1_test_path = '/content/qM-AI-L/QA-Chatbot/Dataset-1/aiml-qa-test.xlsx'
D1_dev_path = '/content/qM-AI-L/QA-Chatbot/Dataset-1/aiml-qa-dev.xlsx'

# %%
D1_train_df = pd.read_excel(D1_train_path)
D1_dev_df = pd.read_excel(D1_dev_path)
D1_test_df = pd.read_excel(D1_test_path)

# %%
D1_train_df.shape, D1_test_df.shape, D1_dev_df.shape
# Out:
# ((1316, 2), (120, 3), (80, 3))

# %%
D1_train_df.columns,  D1_test_df.columns,  D1_dev_df.columns
# Out:
# (Index(['question', 'answer'], dtype='object'),
#  Index(['question', 'answer1', 'answer2'], dtype='object'),
#  Index(['question', 'answer1', 'answer2'], dtype='object'))

# %%
# change column names in D1 df to match with test and dev dfs

D1_train_df = D1_train_df.rename(columns={"answer": "answer1"})

# %%
D1_train_df.columns,  D1_test_df.columns,  D1_dev_df.columns
# Out:
# (Index(['question', 'answer1'], dtype='object'),
#  Index(['question', 'answer1', 'answer2'], dtype='object'),
#  Index(['question', 'answer1', 'answer2'], dtype='object'))

# %% [markdown]
# ## **Add prompt format column to train df for model input**

# %%
#Function for Train dataset
def formatted_train(x):

  instruction = "Generate an answer for the following question in less than two sentences."

  if x['question']:
    formatted_text = f"""Below is an instruction that describes a task. \
    Write a response that appropriately completes the request.

    ### Instruction:
    {instruction}

    ### Input:
    {x['question']}

    ### Response:
    {x['answer1']}<eos>"""

  else:
    formatted_text = f"""Below is an instruction that describes a task. \
    Write a response that appropriately completes the request.

    ### Instruction:
    {instruction}

    ### Response:
    {x['answer1']}<eos>"""

  return formatted_text

# %%
#Function for Test and Dev dataset
def format_test(x):

  instruction = "Generate an answer for the following question in less than two sentences."

  if x['question']:
    formatted_text = f"""Below is an instruction that describes a task. \
    Write a response that appropriately completes the request.

    ### Instruction:
    {instruction}

    ### Input:
    {x['question']}

    ### Response:
    """

  else:
    formatted_text = f"""Below is an instruction that describes a task. \
    Write a response that appropriately completes the request.

    ### Instruction:
    {instruction}

    ### Response:
    """

  return formatted_text

# %%
D1_train_df["formatted_text"] = D1_train_df.apply(formatted_train, axis=1)
D1_test_df["formatted_text"] = D1_test_df.apply(format_test, axis=1)
D1_dev_df["formatted_text"] = D1_dev_df.apply(format_test, axis=1)

# %% [markdown]
# **Check train prompt includes answer column/ data, and test and dev prompts does not include answers/targets**

# %%
D1_train_df['formatted_text'][0]
# Out:
# 'Below is an instruction that describes a task.     Write a response that appropriately completes the request.\n\n    ### Instruction:\n    Generate an answer for the following question in less than two sentences.\n\n    ### Input:\n    What is the difference between concatenation vs. summation of two tensors?\n\n    ### Response:\n    Concatenation combines two tensors by adding them together along a specified dimension. Summation adds the elements of two tensors together element-wise.<eos>'

# %%
D1_test_df['formatted_text'][0]
# Out:
# 'Below is an instruction that describes a task.     Write a response that appropriately completes the request.\n\n    ### Instruction:\n    Generate an answer for the following question in less than two sentences.\n\n    ### Input:\n    How we can effectively convert 2D images to 1D?\n\n    ### Response:\n    '

# %%
D1_dev_df['formatted_text'][0]
# Out:
# "Below is an instruction that describes a task.     Write a response that appropriately completes the request.\n\n    ### Instruction:\n    Generate an answer for the following question in less than two sentences.\n\n    ### Input:\n    Does the maximum value of 'n' in the n-gram model depend on the average number of words per sentence in the training data?\n\n    ### Response:\n    "

# %% [markdown]
# # **Convert DFs to Datasets**

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.21.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
from datasets import Dataset
D1_Train_dataset = Dataset.from_pandas(D1_train_df)
D1_Test_dataset = Dataset.from_pandas(D1_test_df)
D1_Dev_dataset = Dataset.from_pandas(D1_dev_df)

# %%
D1_Train_dataset, D1_Test_dataset, D1_Dev_dataset
# Out:
# (Dataset({
#      features: ['question', 'answer1', 'formatted_text'],
#      num_rows: 1316
#  }),
#  Dataset({
#      features: ['question', 'answer1', 'answer2', 'formatted_text'],
#      num_rows: 120
#  }),
#  Dataset({
#      features: ['question', 'answer1', 'answer2', 'formatted_text'],
#      num_rows: 80
#  }))

# %%
#check train dataset
D1_Train_dataset['formatted_text'][0:2]
# Out:
# ['Below is an instruction that describes a task.     Write a response that appropriately completes the request.\n\n    ### Instruction:\n    Generate an answer for the following question in less than two sentences.\n\n    ### Input:\n    What is the difference between concatenation vs. summation of two tensors?\n\n    ### Response:\n    Concatenation combines two tensors by adding them together along a specified dimension. Summation adds the elements of two tensors together element-wise.<eos>',
#  'Below is an instruction that describes a task.     Write a response that appropriately completes the request.\n\n    ### Instruction:\n    Generate an answer for the following question in less than two sentences.\n\n    ### Input:\n    What is the difference between concatenation vs. summation of two tensors?\n\n    ### Response:\n    Concatenation is often used to combine different features of a data set, such as images and text. Summation is often used to calculate the similarity between two tensors, or to compute the loss function for a neural network.<eos>']

# %% [markdown]
# # **Fine-tuning Google Gemma for Code Dataset**

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

# %%
# Create a PEFT model with the given parameters
model = FastLanguageModel.get_peft_model(
    model,
    r=16, # LoRa Rank
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing=True
)
# Out:
# Unsloth 2024.8 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %%
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = D1_Train_dataset,
    dataset_text_field = "formatted_text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 2,
        warmup_steps = 5,
        max_steps = 30,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "paged_adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)
# Out:
# Map (num_proc=2):   0%|          | 0/1316 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 1,316 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 1 | Gradient Accumulation steps = 2
# \        /    Total batch size = 2 | Total steps = 30
#  "-____-"     Number of trainable parameters = 50,003,968
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 01:00, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.872400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.632200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.516900</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.143400</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.675300</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.427100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.265000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.502900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.108700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.031800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.259100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.352500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.291100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.881600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.921600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.062200</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.891300</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.800700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.998900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.956800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.851400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.922500</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.135600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.829100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.681300</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.846100</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.133000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.840500</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.963800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.577600</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# **#check test data for infrencing and answer generation**

# %%
from transformers import TextStreamer

# %%
D1_test_df['formatted_text'][2], D1_test_df['formatted_text'][3]
# Out:
# ("Below is an instruction that describes a task.     Write a response that appropriately completes the request.\n\n    ### Instruction:\n    Generate an answer for the following question in less than two sentences.\n\n    ### Input:\n    What is NLP's current biggest challenge that is being tried to overcome ?\n\n    ### Response:\n    ",
#  'Below is an instruction that describes a task.     Write a response that appropriately completes the request.\n\n    ### Instruction:\n    Generate an answer for the following question in less than two sentences.\n\n    ### Input:\n    Which problems cannot be solved by Neural networks?\n\n    ### Response:\n    ')

# %% [markdown]
# # **Checkout the trained model generating answer**

# %%
Prompt = D1_test_df['formatted_text'][2]

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    Prompt
], return_tensors = "pt").to("cuda")

text_streamer = TextStreamer(tokenizer)
generated_ids = model.generate(**inputs, streamer=text_streamer, max_new_tokens=512)
# Get the generated text by decoding the IDs
generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True) # Apply to the decoded text
# Out:
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is NLP's current biggest challenge that is being tried to overcome ?
#
#     ### Response:
#     The biggest challenge in NLP is dealing with the vastness and complexity of natural language, including the vastness of vocabulary, the complexity of syntax, and the ambiguity of meaning.<eos>

# %% [markdown]
# # **Function to extract answer part from the model generated response**

# %%
# **Function to extract answer part from the model generated response**
def get_answer(text):
    start_tag = "### Response:"

    # Find the start and end indices
    start_idx = text.find(start_tag)

    # Check if both tags are found
    if start_idx == -1:
        return None  # Tags not found

    # Extract content between the tags
    subject = text[start_idx + len(start_tag):].strip()

    return subject

# %%
get_answer(generated_text)
# Out:
# 'The biggest challenge in NLP is dealing with the vastness and complexity of natural language, including the vastness of vocabulary, the complexity of syntax, and the ambiguity of meaning.'

# %%
D1_test_df.columns, D1_test_df.shape
# Out:
# (Index(['question', 'answer1', 'answer2', 'formatted_text'], dtype='object'),
#  (120, 4))

# %%
original_answers = []
gemma_answers = []

for index, row in D1_test_df.iterrows():
    original_answer = row['answer1']


    Prompt = row['formatted_text']

    # Define the device (GPU if available, otherwise CPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Move both models to the same device
    model.to(device)
    inputs = tokenizer(
    [
        Prompt
    ], return_tensors = "pt").to("cuda")

    text_streamer = TextStreamer(tokenizer)
    generated_ids = model.generate(**inputs, streamer=text_streamer, max_new_tokens=512)
    # Get the generated text by decoding the IDs
    gemma_answer = tokenizer.decode(generated_ids[0], skip_special_tokens=True) # Apply to the decoded text
    gemma_answers.append(get_answer(gemma_answer))


    original_answers.append(original_answer)

zipped_subjects = list(zip(original_answers, gemma_answers))

D1_Test_Gemma_with_Unsloth_df = pd.DataFrame(zipped_subjects, columns = ['original_answers', 'gemma_answers'])
D1_Test_Gemma_with_Unsloth_df
# Out:
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How we can effectively convert 2D images to 1D?
#
#     ### Response:
#     Reshaping the 2D image into a 1D vector is a common approach for converting 2D images to 1D.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can we utilize an autoencoder to perform dimensionality reduction on numerical datasets?
#
#     ### Response:
#     Yes, an autoencoder can be used for dimensionality reduction on numerical datasets by compressing the input data into a lower-dimensional representation.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is NLP's current biggest challenge that is being tried to overcome ?
#
#     ### Response:
#     The biggest challenge in NLP is dealing with the vastness and complexity of natural language, including the vastness of vocabulary, the complexity of syntax, and the ambiguity of meaning.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Which problems cannot be solved by Neural networks?
#
#     ### Response:
#     Neural networks can solve a wide range of problems, including classification, regression, and pattern recognition.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is scaling necessary for SVM?
#
#     ### Response:
#     Yes, scaling is necessary for SVM to ensure that features are comparable and that no single feature dominates the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Adding layer to a machine learning model can lead to overfitting, correct?
#
#     ### Response:
#     Adding more layers to a neural network can increase the model's complexity, leading to overfitting.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     is comparision of model predictions important?
#
#     ### Response:
#     Yes, comparing model predictions can be useful for evaluating model performance and identifying areas for improvement.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the way to invert the association rules?
#
#     ### Response:
#     Inverting association rules involves finding the conditions that are necessary for an event to occur, rather than the conditions that are sufficient.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the good number of filters we can have?
#
#     ### Response:
#     The number of filters in a convolutional layer depends on the problem and the data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How are Part-of-Speech (POS) tags learned in natural language processing?
#
#     ### Response:
#     POS tags are learned through supervised or unsupervised learning algorithms, where the model is trained on a dataset of sentences with their corresponding POS tags.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In the real world, which type of machine learning, supervised or unsupervised learning, has more applications?
#
#     ### Response:
#     Supervised learning is more widely used in real-world applications, as it involves the use of labeled data for training and prediction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     I think Model does not depend upon data volume - could be no. of features, layers, params etc.
#
#     ### Response:
#     Model's complexity and capacity are influenced by the number of features, layers, and parameters.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Dense function does the jobs of Convolution as well as Fully connected layer ?
#
#     ### Response:
#     Dense function is a fully connected layer that connects all neurons in the previous layer to all neurons in the current layer, making it a type of fully connected layer.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When does GloVe doesn't work well?
#
#     ### Response:
#     GloVe is a powerful tool for capturing word relationships, but it may not be suitable for certain tasks or datasets that require more specific or nuanced information.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In which scenarios or contexts do we typically employ a tanh kernel?
#
#     ### Response:
#     The tanh kernel is frequently employed in neural networks for non-linear activation functions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     While training, do we start with random weights for every epoch? Or do we take them from the previous epoch?
#
#     ### Response:
#     During training, the weights are initialized randomly at the beginning of each epoch.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what is compression used in autoencoders?
#
#     ### Response:
#     Compression in autoencoders is used to reduce the size of the input data, allowing for more efficient processing and storage.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it a thumb rule to take log(N) as the window size?
#
#     ### Response:
#     No, it is not a thumb rule to take log(N) as the window size.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How to check the seperability of n-dimensional data?
#
#     ### Response:
#     The separability of n-dimensional data can be checked by using techniques such as linear or non-linear classification algorithms, or by analyzing the data distribution and looking for clusters or patterns that can be separated by a hyperplane.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What should be the length of vector in Word2Vec model?
#
#     ### Response:
#     The length of the vector in Word2Vec model depends on the vocabulary size and the dimension of the vector space.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How is y_pred used in evaluating the performance of a ML model?
#
#     ### Response:
#     y_pred is used to predict the output of a model for a given input, which can then be compared to the actual output to measure the model's accuracy.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Example of a non-parametric model?
#
#     ### Response:
#     Non-parametric models do not have a fixed number of parameters and can adapt to the data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     how 2x2 to 3x3 mapping is happening while sliding
#
#     ### Response:
#     In 2x2 to 3x3 mapping, the input image is convolved with a 3x3 filter, resulting in a 2x2 output.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what are the evalusation methods to determine, if the images have been sufficiently denoised?
#
#     ### Response:
#     The mean square error (MSE) and peak signal-to-noise ratio (PSNR) are two common metrics used to evaluate the quality of denoised images.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How Convolution network works?
#
#     ### Response:
#     Convolutional networks are a type of deep learning model that uses filters to extract features from images or other data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the various data that can be used for machine learning applications, besides images?
#
#     ### Response:
#     Text, audio, and video data are some examples of data that can be used for machine learning applications in addition to images.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can we create clusters using decision trees instead of k-means clustering?
#
#     ### Response:
#     Yes, decision trees can be used to create clusters by splitting data into smaller groups based on specific criteria.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Which are the other kind of problems for which deep learning is used?
#
#     ### Response:
#     Deep learning is used for a wide range of tasks, including image recognition, natural language processing, and time series analysis.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what are the aspects that help select a ML Model?
#
#     ### Response:
#     Model selection is based on factors such as data characteristics, problem type, and model complexity.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is a neuron in neural netwprks in machine learning?
#
#     ### Response:
#     A neuron is a basic unit in neural networks that receives inputs, performs calculations, and produces an output.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the other applications of unsupervised learning than clustering?
#
#     ### Response:
#     Unsupervised learning can be used for feature extraction, anomaly detection, and pattern recognition.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the difference between NLP and speech processing?
#
#     ### Response:
#     NLP focuses on understanding and analyzing text data, while speech processing deals with analyzing and understanding spoken language.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the various initialization methods in a neural network?
#
#     ### Response:
#     In neural networks, initialization methods are used to assign random values to the weights and biases of the network.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the steps of town down approach in hierarchical clustering?
#
#     ### Response:
#     The town down approach in hierarchical clustering involves starting with the most similar pairs of clusters and gradually merging them until all clusters are merged into a single cluster.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it possible to combine speech and video data to enhance the understanding of emotional intelligence?
#
#     ### Response:
#     Yes, combining speech and video data can provide a more comprehensive understanding of emotional intelligence by capturing both verbal and non-verbal cues.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it a good idea to initialize the weights in any neural network as per Gaussian random distribution?
#
#     ### Response:
#     Yes, it is a common practice to initialize the weights in neural networks using a Gaussian distribution, as it helps to avoid the issue of "vanishing gradients" and ensures that the model is not biased towards any particular direction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the reason for making the sample again 100% by adding the replication?
#
#     ### Response:
#     Adding replication to a sample increases its size, making it more representative of the population and reducing bias in the resulting estimates.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can association rules be inverted to identify exceptions, such as items that are not commonly associated with each other?
#
#     ### Response:
#     Yes, association rules can be inverted to identify exceptions, such as items that are not commonly associated with each other.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is stride always choosen as 1 or can it be any number?
#
#     ### Response:
#     Stride can be any number, but it is typically chosen to be an odd number to ensure that the output size is an integer.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How can ImageNet be used to build a custom machine learning model?
#
#     ### Response:
#     ImageNet can be used as a pre-trained model to fine-tune for specific tasks in custom machine learning models.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In the Sequential API, which method is used to specify the optimizer?
#
#     ### Response:
#     In the Sequential API, the optimizer can be specified using the compile() method.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what is CART (Classification and Regression Trees) algorithm?
#
#     ### Response:
#     CART is a decision tree-based algorithm that uses binary splits to create a tree-like structure for classification and regression tasks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the possibilities of number of neurons in the output layer?
#
#     ### Response:
#     The number of neurons in the output layer is determined by the number of classes in the dataset.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How can we incorporate the influence of
# additional features,apart from the
# observation itself?
#
#     ### Response:
#     We can use
# feature engineering techniques
# to transform or combine
# features to create new
# ones that better capture
# the underlying patterns
# in the data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can we apply Autoencoders on numerical datasets for dimentionality reduction?
#
#     ### Response:
#     Yes, Autoencoders can be applied to numerical datasets for dimensionality reduction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How we can apply CNN to text and pictures?
#
#     ### Response:
#     CNNs can be applied to both text and images by using different types of filters and kernels to extract features from the data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Are they not mutually exclusive?
#
#     ### Response:
#     No, they are not mutually exclusive.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the significance of the term "Natural language"? Does this imply the existence of unnatural languages as well?
#
#     ### Response:
#     Natural language refers to the language that humans use in everyday communication, whereas artificial language refers to the language that machines use to communicate with each other.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it possible to associate specific kernel functions with particular problem statements or domains in machine learning?
#
#     ### Response:
#     Yes, specific kernel functions can be used to model certain problem statements or domains in machine learning.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When is backpropagation typically performed in a neural network training process?
#
#     ### Response:
#     Backpropagation is typically performed during the training process of a neural network to update the weights and biases of the network.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is convoluton a dimensionality reduction technique?
#
#     ### Response:
#     No, convolution is not a dimensionality reduction technique. It is a type of operation that involves sliding a filter over an input and producing a new output by combining the values in the filter with the corresponding values in the input.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Are there any databases similar to ImageNet that contain X-Ray images for classifying human diseases?
#
#     ### Response:
#     Yes, there are several databases that contain X-Ray images for classifying human diseases, such as the ChestX-ray14 dataset and the ChestX-ray8 dataset.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     At the beginning of each epoch, do we initialize the weights randomly, or do we use the weights from the previous epoch?
#
#     ### Response:
#     At the beginning of each epoch, the weights are typically initialized randomly, rather than using the weights from the previous epoch.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what's the main objective of this consonant classification in speeech recognition?
#
#     ### Response:
#     The main objective of consonant classification in speech recognition is to accurately identify and distinguish between different consonant sounds in spoken language, which can help improve overall speech recognition accuracy.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can the number of clusters change during the iteration of a clustering algorithm?
#
#     ### Response:
#     Yes, the number of clusters can change during the iteration of a clustering algorithm.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Do search engines also use web scraping?
#
#     ### Response:
#     Yes, search engines can use web scraping to gather data from websites for indexing and ranking purposes.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it generally recommended to initialize the weights (W's) in a neural network using a Gaussian random distribution during the random initialization process?
#
#     ### Response:
#     Yes, it is a common practice to initialize the weights in a neural network using a Gaussian random distribution during the random initialization process.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How is padding useful in image processing?
#
#     ### Response:
#     Padding is used to increase the size of an image, allowing for more context to be considered during processing.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the difference between Natural Language Processing and speech processing?
#
#     ### Response:
#     Natural Language Processing (NLP) focuses on understanding and manipulating human language, while speech processing deals with analyzing and interpreting spoken language.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How can we ensure that models consider external factors, such as the COVID-19 pandemic, which caused sales to decline and no sales during lockdowns?
#
#     ### Response:
#     Including external factors in the model's training data can help it learn to adapt to changing conditions and make more accurate predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are different activation functions in a NN?
#
#     ### Response:
#     Activation functions are non-linear functions that are used to introduce non-linearity in neural networks, allowing them to model complex relationships in data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is convolution primarily used to reduce
# dimensionality in neural networks?
#
#     ### Response:
#     Yes, convolution is frequently used
# to reduce the dimensionality of
# data in neural networks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     During the preprocessing of data, how can anomalies be identified?
#
#     ### Response:
#     Anomalies can be identified by analyzing the data and looking for unusual or unexpected patterns or values.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How important is data mining in the context of machine learning and artificial intelligence?
#
#     ### Response:
#     Data mining is a crucial component of machine learning and AI, as it enables the extraction of valuable insights and patterns from large datasets.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the reason behind choosing max pooling instead of average pooling?
#
#     ### Response:
#     Max pooling is often preferred over average pooling because it helps to preserve the most significant features in the data, leading to better classification performance.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     does the 1st dense includes 1 hidden layer alongwith input layer or just input layer?
#
#     ### Response:
#     The first dense layer in a neural network typically includes both the input layer and a hidden layer.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Compare Gassian random distribution against other methods of intialization?
#
#     ### Response:
#     Gaussian random distribution is a popular method for initializing weights in neural networks, as it helps to break symmetry and avoid local minima.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     does this data thumb rule apply for both classification & regression problems?
#
#     ### Response:
#     The data thumb rule for the number of observations to features ratio is a general guideline that applies to both classification and regression problems.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How does the mapping from a 2x2 input to a 3x3 output occur during sliding in convolutional operations?
#
#     ### Response:
#     The 3x3 output is created by taking a 3x3 window and sliding it over the 2x2 input, resulting in a 3x3 output.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can it be controlled by human?
#
#     ### Response:
#     No, GANs are not directly controlled by humans.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Give one example where y_pred is used?
#
#     ### Response:
#     y_pred is used in machine learning to predict the output of a model for a given input.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does dataset need to have same number of samples in each class for model training?
#
#     ### Response:
#     No, the dataset does not need to have the same number of samples in each class for model training.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How to ensure models consider external impacts like COVID-related sales decline during lockdowns?
#
#     ### Response:
#     Including external factors such as COVID-related sales decline in the model can help ensure that the model considers external impacts and provides more accurate predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the applications of Autoencoder and PCA?
#
#     ### Response:
#     Autoencoders are used for data compression and feature extraction, while PCA is used for dimensionality reduction and feature extraction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How to leverage pretrained models for any specific machine learning task?
#
#     ### Response:
#     Pre-trained models can be fine-tuned for specific tasks by adjusting the model's parameters and adding task-specific layers.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Whether the "images" in later layers of a CNN are actually images or just interpreted as images due to RGB logic?
#
#     ### Response:
#     The "images" in later layers of a CNN are not actual images, but rather feature maps that represent the extracted patterns and characteristics of the input data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is deep learning only used for classification problems?
#
#     ### Response:
#     No, deep learning can be applied to a wide range of tasks, including classification, regression, and clustering.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is there any sub-branch of Speech recognition deals with converting brain electrical signals to speech ?
#
#     ### Response:
#     Yes, there is a sub-branch of speech recognition called electroencephalography (EEG) that deals with converting brain electrical signals to speech.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When or where do Validating constraints or rules such as height-weight ratios, volume-density relationships, or any other domain-specific constraints in a neural network takes place?
#
#     ### Response:
#     Validating constraints or rules in neural networks can be applied at different stages of the model development process, including during model design, data preparation, and model training.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it possible for a model to fail in properly grouping certain data points? What steps should be taken in such a scenario?
#
#     ### Response:
#     Yes, it is possible for a model to fail in properly grouping certain data points. This can be due to overfitting, underfitting, or bias in the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How does the mapping from a 2x2 to a 3x3 size occur during the sliding process?
#
#     ### Response:
#     The 2x2 input is expanded to a 3x3 size by adding two additional pixels on each side, allowing for a 3x3 filter to be applied during the sliding process.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the difference between NLP and speech processing?
#
#     ### Response:
#     NLP focuses on understanding and analyzing text data, while speech processing deals with analyzing and understanding spoken language.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is data normalization/scaling applicable in the context of speech recognition?
#
#     ### Response:
#     Data normalization/scaling can be beneficial in speech recognition tasks, as it can help to reduce the impact of outliers and improve the performance of the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In CNNs, how can we visualize layers and filters? Do we interpret the weights as RGB pixel values, and how do we handle values beyond the 0-255 range? Maintain the context in the rephrased question.
#
#     ### Response:
#     In CNNs, we can visualize the filters and layers by interpreting the weights as RGB pixel values. However, we need to normalize the values to the 0-255 range for better visualization.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How we can load bin file?
#
#     ### Response:
#     Bin files can be loaded using the load() function in Python.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the reasons for using max pooling instead of average pooling? Provide insights into the context of choosing max pooling.
#
#     ### Response:
#     Max pooling is often preferred over average pooling because it helps to preserve the most significant features in the data, which can be useful for classification tasks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the purpose of using a limit or max limit in a given context?
#
#     ### Response:
#     Limiting the number of elements in a set or sequence can help to reduce complexity and improve performance.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is clustering a suitable technique for determining the optimal placement of Content Delivery Networks (CDNs) in cloud infrastructure?
#
#     ### Response:
#     Yes, clustering can be used to identify the optimal locations for CDNs in cloud infrastructure.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Mention few methods used for cutting neural networks?
#
#     ### Response:
#     Pruning, Quantization, and Distillation are some methods used for cutting neural networks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does Unsupervised Learning solely apply to 'grouping' or 'clustering'? Are there other applications for unsupervised learning?
#
#     ### Response:
#     Unsupervised learning is a type of machine learning that focuses on discovering patterns and relationships in data without the need for labeled training data. It can be used for a variety of tasks, including clustering, anomaly detection, and feature extraction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How do discrimination and reliability differ from each other?
#
#     ### Response:
#     Discrimination refers to the ability of a model to correctly classify samples, while reliability refers to the model's ability to consistently produce accurate predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Which holds more signficance: classification or regression?
#
#     ### Response:
#     Both classification and regression are important in machine learning, depending on the problem at hand.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it recommended to use MATLAB for speech processing?
#
#     ### Response:
#     Yes, MATLAB is a powerful tool for speech processing, providing a range of built-in functions and toolboxes for tasks such as feature extraction, classification, and analysis.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it always feasible to transform data to a linearly separable form by increasing the dimensionality by one?
#
#     ### Response:
#     No, increasing the dimensionality by one may not always result in a linearly separable form.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How does window size parameter affect the context of a given word in NLP?
#
#     ### Response:
#     The window size parameter in NLP determines the context of a word by considering the surrounding words within a certain range.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it necessary to comprehend the features
# extracted by CNN or can we simply feed
# them into Random Forest and let the
# machine handle the task?
# Why is backpropagation not applicable to
# Random Forest, and what are the reasons behind it?
#
#     ### Response:
#     Random Forest is a non-parametric
# algorithm that does not require
# backpropagation. It uses bagging to
# create multiple decision trees, each
# trained on a different subset of the
# data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How do any constraint/rules like height weight ,or volume density,fit etc can be validated in neural networks, at which layer?
#
#     ### Response:
#     Constraints like height, weight, volume, and density can be validated in neural networks at the input layer, where they are used to transform the input data into a suitable format for the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can self-supervised learning be the apt approach for fraud detection where count of true positives is very low in reality?
#
#     ### Response:
#     Self-supervised learning can be an effective approach for fraud detection, as it can extract meaningful representations from unlabeled data and identify patterns that may indicate fraudulent activity.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In simple terms, how is feedback different from backpropagation in the context of neural networks?
#
#     ### Response:
#     Backpropagation is a method used to update the weights in a neural network, while feedback refers to the process of providing information about the model's performance to the user.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it appropriate to interpret the weights as RGB pixel values? What occurs when certain numbers exceed the 0-255 range?
#
#     ### Response:
#     No, the weights are not directly related to RGB pixel values. They are used to represent the importance of each feature in the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can RGBa images be considered as a 4D array in image processing?
#
#     ### Response:
#     Yes, RGBa images can be considered as a 4D array in image processing, where the 4th dimension represents the alpha channel.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the differences between using batch training and stochastic gradient descent (SGD) in neural network optimization? Maintain the context in the rephrased question.
#
#     ### Response:
#     Batch training refers to training the model on a fixed number of samples at once, while SGD trains the model on a single sample at a time.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what does X.ndim do in pytorch? What is the equivalent function in tensorflow package?
#
#     ### Response:
#     X.ndim in PyTorch refers to the number of dimensions in a tensor. The equivalent function in TensorFlow is tf.shape, which returns the shape of a tensor as a tuple.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Will slow compression over many layers & abrupt expansion over few layers lead to data loss in autoencoder?
#
#     ### Response:
#     Yes, it is possible that slow compression over many layers and abrupt expansion over few layers can lead to data loss in an autoencoder.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can FAQ bots be developed or constructed using Interactive ML?
#
#     ### Response:
#     Yes, FAQ bots can be developed using Interactive ML, which involves collecting and analyzing user interactions to improve the bot's responses over time.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does user controls the number of features to be selected in each tree of a Random Forest model a hyperparameter ?
#
#     ### Response:
#     Yes, the number of features to be considered at each split in a Random Forest model is a hyperparameter that can be tuned to improve model performance.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When is backpropagation performed in neural networks, and what is its role in the learning process? Maintain the context in the rephrased question.
#
#     ### Response:
#     Backpropagation is a method used to update the weights in neural networks during the training process. It helps the network learn from its mistakes and improve its predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the primary challenge in current NLP research that researchers are actively working to overcome?
#
#     ### Response:
#     The primary challenge in current NLP research is the ability to understand and generate human-like responses in natural language.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is MSE the only loss function used for
# time series, or can other loss functions
# also be applied?
#
#     ### Response:
#     Yes, other loss functions can be used
# for time series analysis, such as
# mean absolute error (MAE) and
# mean absolute percentage error
# (MAPE).<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     where do we use cartesian?
#
#     ### Response:
#     Cartesian coordinates are used to represent a point in a two-dimensional space by specifying its x and y coordinates.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the cross Entropy loss? Is that same as Misclassfication rate?
#
#     ### Response:
#     Cross-entropy loss is a measure of the difference between the predicted and actual probabilities, while misclassification rate is a measure of the proportion of incorrect predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the significance of data mining with ML and AI? How does it differ from traditional data mining, where predictions are left to humans, while ML can make predictions for humans?
#
#     ### Response:
#     Data mining with ML and AI is a more advanced approach that uses algorithms to automatically extract patterns and insights from data, making predictions and recommendations without human intervention.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does backpropagation occur exclusively in the fully connected layer, or does it involve other layers in the neural network? Maintain the context in the rephrased question.
#
#     ### Response:
#     Backpropagation is a technique used to update the weights in the neural network, and it can occur in any layer, including fully connected layers, convolutional layers, and recurrent layers.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it ideal for autoencoders to be symmetric? Could slow compression over many layers and abrupt expansion over a few layers lead to data loss?
#
#     ### Response:
#     Yes, it is ideal for autoencoders to be symmetric, as it helps to avoid data loss and ensures that the input and output dimensions are the same.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can autoencoders be used as a dimensionality reduction tool, similar to PCA, in supervised learning scenarios?
#
#     ### Response:
#     Yes, autoencoders can be used as a dimensionality reduction tool in supervised learning scenarios, as they can extract relevant features and reduce the input data's dimension.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can you repeat difference between data mining and machine learning
#
#     ### Response:
#     Data mining is a process of discovering patterns and relationships in large datasets, while machine learning is a subset of AI that focuses on building algorithms that can learn and make predictions based on data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is there any software available for clinical language annotation?
#
#     ### Response:
#     Yes, there are several tools available for clinical language annotation, such as the Clinical Text Annotation (CTA) tool, which is designed specifically for clinical text annotation.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When do we slice?
#
#     ### Response:
#     Slicing is used to extract a specific part of an array or tensor.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In terms of obtaining better context, is lemmatization generally considered superior to stemming?
#
#     ### Response:
#     In general, lemmatization is considered to be a more effective approach than stemming for obtaining better context in natural language processing tasks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does the kernel provide information about the higher dimension count?
#
#     ### Response:
#     The kernel in a neural network provides information about the number of filters or channels in each layer.<eos>
#                                       original_answers  \
# 0    Converting images to 1D data may not be effect...
# 1    Yes, autoencoders can be applied to numerical ...
# 2    The main challenges of NLP is finding and coll...
# 3    While neural networks have shown great success...
# 4    Yes, scaling the input data is generally recom...
# ..                                                 ...
# 115  Data mining refers to the process of discoveri...
# 116  CLAMP (Clinical Language Annotation, Modeling,...
# 117  Slicing is a useful technique in Python for ex...
# 118  Yes, lemmatization is generally considered bet...
# 119  The kernel in machine learning doesn't directl...
#
#                                          gemma_answers
# 0    Reshaping the 2D image into a 1D vector is a c...
# 1    Yes, an autoencoder can be used for dimensiona...
# 2    The biggest challenge in NLP is dealing with t...
# 3    Neural networks can solve a wide range of prob...
# 4    Yes, scaling is necessary for SVM to ensure th...
# ..                                                 ...
# 115  Data mining is a process of discovering patter...
# 116  Yes, there are several tools available for cli...
# 117  Slicing is used to extract a specific part of ...
# 118  In general, lemmatization is considered to be ...
# 119  The kernel in a neural network provides inform...
#
# [120 rows x 2 columns]

# %% [markdown]
# # ** Evaluate model performance- Rouge**

# %%
# !pip install rouge-score  # Install the rouge-score library
from rouge_score import rouge_scorer
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.5)

# %%
D1_test_scores = D1_Test_Gemma_with_Unsloth_df.copy()

# %%
from rouge_score import rouge_scorer

def calculate_rouge(reference, hypothesis):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL', 'rougeLsum'], use_stemmer=True) # Instantiate a RougeScorer object
    scores = scorer.score(reference, hypothesis) # Call the score method on the RougeScorer object
    return {metric: score.fmeasure for metric, score in scores.items()}

# Apply ROUGE score calculation to each row
D1_test_scores['rouge_scores'] = D1_test_scores.apply(lambda row: calculate_rouge(row['original_answers'], row['gemma_answers']), axis=1)

# %%
D1_test_scores
# Out:
#                                       original_answers  \
# 0    Converting images to 1D data may not be effect...
# 1    Yes, autoencoders can be applied to numerical ...
# 2    The main challenges of NLP is finding and coll...
# 3    While neural networks have shown great success...
# 4    Yes, scaling the input data is generally recom...
# ..                                                 ...
# 115  Data mining refers to the process of discoveri...
# 116  CLAMP (Clinical Language Annotation, Modeling,...
# 117  Slicing is a useful technique in Python for ex...
# 118  Yes, lemmatization is generally considered bet...
# 119  The kernel in machine learning doesn't directl...
#
#                                          gemma_answers  \
# 0    Reshaping the 2D image into a 1D vector is a c...
# 1    Yes, an autoencoder can be used for dimensiona...
# 2    The biggest challenge in NLP is dealing with t...
# 3    Neural networks can solve a wide range of prob...
# 4    Yes, scaling is necessary for SVM to ensure th...
# ..                                                 ...
# 115  Data mining is a process of discovering patter...
# 116  Yes, there are several tools available for cli...
# 117  Slicing is used to extract a specific part of ...
# 118  In general, lemmatization is considered to be ...
# 119  The kernel in a neural network provides inform...
#
#                                           rouge_scores
# 0    {'rouge1': 0.3555555555555555, 'rouge2': 0.093...
# 1    {'rouge1': 0.6666666666666667, 'rouge2': 0.244...
# 2    {'rouge1': 0.28571428571428575, 'rouge2': 0.03...
# 3    {'rouge1': 0.18604651162790697, 'rouge2': 0.09...
# 4    {'rouge1': 0.30188679245283023, 'rouge2': 0.03...
# ..                                                 ...
# 115  {'rouge1': 0.4, 'rouge2': 0.20833333333333334,...
# 116  {'rouge1': 0.3018867924528302, 'rouge2': 0.156...
# 117  {'rouge1': 0.5, 'rouge2': 0.13333333333333333,...
# 118  {'rouge1': 0.5000000000000001, 'rouge2': 0.176...
# 119  {'rouge1': 0.380952380952381, 'rouge2': 0.25, ...
#
# [120 rows x 3 columns]

# %%
pd.json_normalize(D1_test_scores['rouge_scores'])
# Out:
#        rouge1    rouge2    rougeL  rougeLsum
# 0    0.355556  0.093023  0.222222   0.222222
# 1    0.666667  0.244898  0.470588   0.470588
# 2    0.285714  0.032787  0.253968   0.253968
# 3    0.186047  0.097561  0.186047   0.186047
# 4    0.301887  0.039216  0.264151   0.264151
# ..        ...       ...       ...        ...
# 115  0.400000  0.208333  0.360000   0.360000
# 116  0.301887  0.156863  0.264151   0.264151
# 117  0.500000  0.133333  0.437500   0.437500
# 118  0.500000  0.176471  0.388889   0.388889
# 119  0.380952  0.250000  0.333333   0.333333
#
# [120 rows x 4 columns]

# %%
D1_test_scores = pd.concat([D1_test_scores, pd.json_normalize(D1_test_scores['rouge_scores'])], axis=1)

# %%
D1_test_scores
# Out:
#                                       original_answers  \
# 0    Converting images to 1D data may not be effect...
# 1    Yes, autoencoders can be applied to numerical ...
# 2    The main challenges of NLP is finding and coll...
# 3    While neural networks have shown great success...
# 4    Yes, scaling the input data is generally recom...
# ..                                                 ...
# 115  Data mining refers to the process of discoveri...
# 116  CLAMP (Clinical Language Annotation, Modeling,...
# 117  Slicing is a useful technique in Python for ex...
# 118  Yes, lemmatization is generally considered bet...
# 119  The kernel in machine learning doesn't directl...
#
#                                          gemma_answers  \
# 0    Reshaping the 2D image into a 1D vector is a c...
# 1    Yes, an autoencoder can be used for dimensiona...
# 2    The biggest challenge in NLP is dealing with t...
# 3    Neural networks can solve a wide range of prob...
# 4    Yes, scaling is necessary for SVM to ensure th...
# ..                                                 ...
# 115  Data mining is a process of discovering patter...
# 116  Yes, there are several tools available for cli...
# 117  Slicing is used to extract a specific part of ...
# 118  In general, lemmatization is considered to be ...
# 119  The kernel in a neural network provides inform...
#
#                                           rouge_scores    rouge1    rouge2  \
# 0    {'rouge1': 0.3555555555555555, 'rouge2': 0.093...  0.355556  0.093023
# 1    {'rouge1': 0.6666666666666667, 'rouge2': 0.244...  0.666667  0.244898
# 2    {'rouge1': 0.28571428571428575, 'rouge2': 0.03...  0.285714  0.032787
# 3    {'rouge1': 0.18604651162790697, 'rouge2': 0.09...  0.186047  0.097561
# 4    {'rouge1': 0.30188679245283023, 'rouge2': 0.03...  0.301887  0.039216
# ..                                                 ...       ...       ...
# 115  {'rouge1': 0.4, 'rouge2': 0.20833333333333334,...  0.400000  0.208333
# 116  {'rouge1': 0.3018867924528302, 'rouge2': 0.156...  0.301887  0.156863
# 117  {'rouge1': 0.5, 'rouge2': 0.13333333333333333,...  0.500000  0.133333
# 118  {'rouge1': 0.5000000000000001, 'rouge2': 0.176...  0.500000  0.176471
# 119  {'rouge1': 0.380952380952381, 'rouge2': 0.25, ...  0.380952  0.250000
#
#        rougeL  rougeLsum
# 0    0.222222   0.222222
# 1    0.470588   0.470588
# 2    0.253968   0.253968
# 3    0.186047   0.186047
# 4    0.264151   0.264151
# ..        ...        ...
# 115  0.360000   0.360000
# 116  0.264151   0.264151
# 117  0.437500   0.437500
# 118  0.388889   0.388889
# 119  0.333333   0.333333
#
# [120 rows x 7 columns]

# %%
# !pip install nltk sacrebleu
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.10.1)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)

# %%
import sacrebleu
from nltk.translate import meteor_score
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Tokenization function
def tokenize(text):
    return text.lower().split()

# %%
def calculate_bleu(reference, hypothesis):
    # BLEU requires tokenized input for reference, but not for hypothesis
    reference = [tokenize(reference)]
    bleu = sacrebleu.corpus_bleu([hypothesis], reference) # hypothesis should be a string
    return bleu.score


D1_test_scores['bleu_score'] = D1_test_scores.apply(lambda row: calculate_bleu(row['original_answers'], row['gemma_answers']), axis=1)

# Calculate METEOR score
def calculate_meteor(reference, hypothesis):
    # Tokenize both reference and hypothesis
    tokenized_reference = tokenize(reference)
    tokenized_hypothesis = tokenize(hypothesis)
    return meteor_score.single_meteor_score(tokenized_reference, tokenized_hypothesis)  # Pass tokenized inputs

D1_test_scores['meteor_score'] = D1_test_scores.apply(lambda row: calculate_meteor(row['original_answers'], row['gemma_answers']), axis=1)

# %%
D1_test_scores
# Out:
#                                       original_answers  \
# 0    Converting images to 1D data may not be effect...
# 1    Yes, autoencoders can be applied to numerical ...
# 2    The main challenges of NLP is finding and coll...
# 3    While neural networks have shown great success...
# 4    Yes, scaling the input data is generally recom...
# ..                                                 ...
# 115  Data mining refers to the process of discoveri...
# 116  CLAMP (Clinical Language Annotation, Modeling,...
# 117  Slicing is a useful technique in Python for ex...
# 118  Yes, lemmatization is generally considered bet...
# 119  The kernel in machine learning doesn't directl...
#
#                                          gemma_answers  \
# 0    Reshaping the 2D image into a 1D vector is a c...
# 1    Yes, an autoencoder can be used for dimensiona...
# 2    The biggest challenge in NLP is dealing with t...
# 3    Neural networks can solve a wide range of prob...
# 4    Yes, scaling is necessary for SVM to ensure th...
# ..                                                 ...
# 115  Data mining is a process of discovering patter...
# 116  Yes, there are several tools available for cli...
# 117  Slicing is used to extract a specific part of ...
# 118  In general, lemmatization is considered to be ...
# 119  The kernel in a neural network provides inform...
#
#                                           rouge_scores    rouge1    rouge2  \
# 0    {'rouge1': 0.3555555555555555, 'rouge2': 0.093...  0.355556  0.093023
# 1    {'rouge1': 0.6666666666666667, 'rouge2': 0.244...  0.666667  0.244898
# 2    {'rouge1': 0.28571428571428575, 'rouge2': 0.03...  0.285714  0.032787
# 3    {'rouge1': 0.18604651162790697, 'rouge2': 0.09...  0.186047  0.097561
# 4    {'rouge1': 0.30188679245283023, 'rouge2': 0.03...  0.301887  0.039216
# ..                                                 ...       ...       ...
# 115  {'rouge1': 0.4, 'rouge2': 0.20833333333333334,...  0.400000  0.208333
# 116  {'rouge1': 0.3018867924528302, 'rouge2': 0.156...  0.301887  0.156863
# 117  {'rouge1': 0.5, 'rouge2': 0.13333333333333333,...  0.500000  0.133333
# 118  {'rouge1': 0.5000000000000001, 'rouge2': 0.176...  0.500000  0.176471
# 119  {'rouge1': 0.380952380952381, 'rouge2': 0.25, ...  0.380952  0.250000
#
#        rougeL  rougeLsum  bleu_score  meteor_score
# 0    0.222222   0.222222    2.024446      0.134100
# 1    0.470588   0.470588    1.646664      0.447695
# 2    0.253968   0.253968    1.123100      0.138037
# 3    0.186047   0.186047    0.000000      0.095714
# 4    0.264151   0.264151    1.727224      0.167833
# ..        ...        ...         ...           ...
# 115  0.360000   0.360000    0.996419      0.282113
# 116  0.264151   0.264151    0.000000      0.270132
# 117  0.437500   0.437500    0.000000      0.260648
# 118  0.388889   0.388889    1.573293      0.474557
# 119  0.333333   0.333333    2.024446      0.333333
#
# [120 rows x 9 columns]

# %%
average_scores = {
    'average_rouge1': D1_test_scores['rouge1'].mean(),
    'average_rouge2': D1_test_scores['rouge2'].mean(),
    'average_rougeL': D1_test_scores['rougeL'].mean(),
    'average_rougeLsum': D1_test_scores['rougeLsum'].mean(),
    'average_bleu_score': D1_test_scores['bleu_score'].mean(),
    'average_meteor_score': D1_test_scores['meteor_score'].mean(),
}

# %%
print("Average Scores for Dataset-1 (Test-Answer-1) QnA task using Gemma_7b_with_Unsloth model:\n")
for metric, score in average_scores.items():
    print(f"{metric}: {score:.4f}")
# Out:
# Average Scores for Dataset-1 (Test-Answer-1) QnA task using Gemma_7b_with_Unsloth model:
#
# average_rouge1: 0.4191
# average_rouge2: 0.1880
# average_rougeL: 0.3363
# average_rougeLsum: 0.3395
# average_bleu_score: 0.9853
# average_meteor_score: 0.2848

# %% [markdown]
# # **Repeat above evaluation process for the 2nd Answer annotation**

# %%
original_answers = []
gemma_answers = []

for index, row in D1_test_df.iterrows():
    original_answer = row['answer2']


    Prompt = row['formatted_text']

    # Define the device (GPU if available, otherwise CPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Move both models to the same device
    model.to(device)
    inputs = tokenizer(
    [
        Prompt
    ], return_tensors = "pt").to("cuda")

    text_streamer = TextStreamer(tokenizer)
    generated_ids = model.generate(**inputs, streamer=text_streamer, max_new_tokens=512)
    # Get the generated text by decoding the IDs
    gemma_answer = tokenizer.decode(generated_ids[0], skip_special_tokens=True) # Apply to the decoded text
    gemma_answers.append(get_answer(gemma_answer))


    original_answers.append(original_answer)

zipped_subjects = list(zip(original_answers, gemma_answers))

D1_Test_Gemma_with_Unsloth_df_A2 = pd.DataFrame(zipped_subjects, columns = ['answer-2', 'gemma_answers'])
D1_Test_Gemma_with_Unsloth_df_A2
# Out:
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How we can effectively convert 2D images to 1D?
#
#     ### Response:
#     Reshaping the 2D image into a 1D vector is a common approach for converting 2D images to 1D.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can we utilize an autoencoder to perform dimensionality reduction on numerical datasets?
#
#     ### Response:
#     Yes, an autoencoder can be used for dimensionality reduction on numerical datasets by compressing the input data into a lower-dimensional representation.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is NLP's current biggest challenge that is being tried to overcome ?
#
#     ### Response:
#     The biggest challenge in NLP is dealing with the vastness and complexity of natural language, including the vastness of vocabulary, the complexity of syntax, and the ambiguity of meaning.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Which problems cannot be solved by Neural networks?
#
#     ### Response:
#     Neural networks can solve a wide range of problems, including classification, regression, and pattern recognition.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is scaling necessary for SVM?
#
#     ### Response:
#     Yes, scaling is necessary for SVM to ensure that features are comparable and that no single feature dominates the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Adding layer to a machine learning model can lead to overfitting, correct?
#
#     ### Response:
#     Adding more layers to a neural network can increase the model's complexity, leading to overfitting.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     is comparision of model predictions important?
#
#     ### Response:
#     Yes, comparing model predictions can be useful for evaluating model performance and identifying areas for improvement.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the way to invert the association rules?
#
#     ### Response:
#     Inverting association rules involves finding the conditions that are necessary for an event to occur, rather than the conditions that are sufficient.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the good number of filters we can have?
#
#     ### Response:
#     The number of filters in a convolutional layer depends on the problem and the data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How are Part-of-Speech (POS) tags learned in natural language processing?
#
#     ### Response:
#     POS tags are learned through supervised or unsupervised learning algorithms, where the model is trained on a dataset of sentences with their corresponding POS tags.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In the real world, which type of machine learning, supervised or unsupervised learning, has more applications?
#
#     ### Response:
#     Supervised learning is more widely used in real-world applications, as it involves the use of labeled data for training and prediction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     I think Model does not depend upon data volume - could be no. of features, layers, params etc.
#
#     ### Response:
#     Model's complexity and capacity are influenced by the number of features, layers, and parameters.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Dense function does the jobs of Convolution as well as Fully connected layer ?
#
#     ### Response:
#     Dense function is a fully connected layer that connects all neurons in the previous layer to all neurons in the current layer, making it a type of fully connected layer.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When does GloVe doesn't work well?
#
#     ### Response:
#     GloVe is a powerful tool for capturing word relationships, but it may not be suitable for certain tasks or datasets that require more specific or nuanced information.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In which scenarios or contexts do we typically employ a tanh kernel?
#
#     ### Response:
#     The tanh kernel is frequently employed in neural networks for non-linear activation functions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     While training, do we start with random weights for every epoch? Or do we take them from the previous epoch?
#
#     ### Response:
#     During training, the weights are initialized randomly at the beginning of each epoch.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what is compression used in autoencoders?
#
#     ### Response:
#     Compression in autoencoders is used to reduce the size of the input data, allowing for more efficient processing and storage.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it a thumb rule to take log(N) as the window size?
#
#     ### Response:
#     No, it is not a thumb rule to take log(N) as the window size.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How to check the seperability of n-dimensional data?
#
#     ### Response:
#     The separability of n-dimensional data can be checked by using techniques such as linear or non-linear classification algorithms, or by analyzing the data distribution and looking for clusters or patterns that can be separated by a hyperplane.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What should be the length of vector in Word2Vec model?
#
#     ### Response:
#     The length of the vector in Word2Vec model depends on the vocabulary size and the dimension of the vector space.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How is y_pred used in evaluating the performance of a ML model?
#
#     ### Response:
#     y_pred is used to predict the output of a model for a given input, which can then be compared to the actual output to measure the model's accuracy.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Example of a non-parametric model?
#
#     ### Response:
#     Non-parametric models do not have a fixed number of parameters and can adapt to the data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     how 2x2 to 3x3 mapping is happening while sliding
#
#     ### Response:
#     In 2x2 to 3x3 mapping, the input image is convolved with a 3x3 filter, resulting in a 2x2 output.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what are the evalusation methods to determine, if the images have been sufficiently denoised?
#
#     ### Response:
#     The mean square error (MSE) and peak signal-to-noise ratio (PSNR) are two common metrics used to evaluate the quality of denoised images.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How Convolution network works?
#
#     ### Response:
#     Convolutional networks are a type of deep learning model that uses filters to extract features from images or other data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the various data that can be used for machine learning applications, besides images?
#
#     ### Response:
#     Text, audio, and video data are some examples of data that can be used for machine learning applications in addition to images.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can we create clusters using decision trees instead of k-means clustering?
#
#     ### Response:
#     Yes, decision trees can be used to create clusters by splitting data into smaller groups based on specific criteria.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Which are the other kind of problems for which deep learning is used?
#
#     ### Response:
#     Deep learning is used for a wide range of tasks, including image recognition, natural language processing, and time series analysis.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what are the aspects that help select a ML Model?
#
#     ### Response:
#     Model selection is based on factors such as data characteristics, problem type, and model complexity.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is a neuron in neural netwprks in machine learning?
#
#     ### Response:
#     A neuron is a basic unit in neural networks that receives inputs, performs calculations, and produces an output.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the other applications of unsupervised learning than clustering?
#
#     ### Response:
#     Unsupervised learning can be used for feature extraction, anomaly detection, and pattern recognition.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the difference between NLP and speech processing?
#
#     ### Response:
#     NLP focuses on understanding and analyzing text data, while speech processing deals with analyzing and understanding spoken language.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the various initialization methods in a neural network?
#
#     ### Response:
#     In neural networks, initialization methods are used to assign random values to the weights and biases of the network.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the steps of town down approach in hierarchical clustering?
#
#     ### Response:
#     The town down approach in hierarchical clustering involves starting with the most similar pairs of clusters and gradually merging them until all clusters are merged into a single cluster.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it possible to combine speech and video data to enhance the understanding of emotional intelligence?
#
#     ### Response:
#     Yes, combining speech and video data can provide a more comprehensive understanding of emotional intelligence by capturing both verbal and non-verbal cues.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it a good idea to initialize the weights in any neural network as per Gaussian random distribution?
#
#     ### Response:
#     Yes, it is a common practice to initialize the weights in neural networks using a Gaussian distribution, as it helps to avoid the issue of "vanishing gradients" and ensures that the model is not biased towards any particular direction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the reason for making the sample again 100% by adding the replication?
#
#     ### Response:
#     Adding replication to a sample increases its size, making it more representative of the population and reducing bias in the resulting estimates.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can association rules be inverted to identify exceptions, such as items that are not commonly associated with each other?
#
#     ### Response:
#     Yes, association rules can be inverted to identify exceptions, such as items that are not commonly associated with each other.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is stride always choosen as 1 or can it be any number?
#
#     ### Response:
#     Stride can be any number, but it is typically chosen to be an odd number to ensure that the output size is an integer.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How can ImageNet be used to build a custom machine learning model?
#
#     ### Response:
#     ImageNet can be used as a pre-trained model to fine-tune for specific tasks in custom machine learning models.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In the Sequential API, which method is used to specify the optimizer?
#
#     ### Response:
#     In the Sequential API, the optimizer can be specified using the compile() method.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what is CART (Classification and Regression Trees) algorithm?
#
#     ### Response:
#     CART is a decision tree-based algorithm that uses binary splits to create a tree-like structure for classification and regression tasks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the possibilities of number of neurons in the output layer?
#
#     ### Response:
#     The number of neurons in the output layer is determined by the number of classes in the dataset.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How can we incorporate the influence of
# additional features,apart from the
# observation itself?
#
#     ### Response:
#     We can use
# feature engineering techniques
# to transform or combine
# features to create new
# ones that better capture
# the underlying patterns
# in the data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can we apply Autoencoders on numerical datasets for dimentionality reduction?
#
#     ### Response:
#     Yes, Autoencoders can be applied to numerical datasets for dimensionality reduction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How we can apply CNN to text and pictures?
#
#     ### Response:
#     CNNs can be applied to both text and images by using different types of filters and kernels to extract features from the data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Are they not mutually exclusive?
#
#     ### Response:
#     No, they are not mutually exclusive.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the significance of the term "Natural language"? Does this imply the existence of unnatural languages as well?
#
#     ### Response:
#     Natural language refers to the language that humans use in everyday communication, whereas artificial language refers to the language that machines use to communicate with each other.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it possible to associate specific kernel functions with particular problem statements or domains in machine learning?
#
#     ### Response:
#     Yes, specific kernel functions can be used to model certain problem statements or domains in machine learning.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When is backpropagation typically performed in a neural network training process?
#
#     ### Response:
#     Backpropagation is typically performed during the training process of a neural network to update the weights and biases of the network.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is convoluton a dimensionality reduction technique?
#
#     ### Response:
#     No, convolution is not a dimensionality reduction technique. It is a type of operation that involves sliding a filter over an input and producing a new output by combining the values in the filter with the corresponding values in the input.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Are there any databases similar to ImageNet that contain X-Ray images for classifying human diseases?
#
#     ### Response:
#     Yes, there are several databases that contain X-Ray images for classifying human diseases, such as the ChestX-ray14 dataset and the ChestX-ray8 dataset.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     At the beginning of each epoch, do we initialize the weights randomly, or do we use the weights from the previous epoch?
#
#     ### Response:
#     At the beginning of each epoch, the weights are typically initialized randomly, rather than using the weights from the previous epoch.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what's the main objective of this consonant classification in speeech recognition?
#
#     ### Response:
#     The main objective of consonant classification in speech recognition is to accurately identify and distinguish between different consonant sounds in spoken language, which can help improve overall speech recognition accuracy.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can the number of clusters change during the iteration of a clustering algorithm?
#
#     ### Response:
#     Yes, the number of clusters can change during the iteration of a clustering algorithm.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Do search engines also use web scraping?
#
#     ### Response:
#     Yes, search engines can use web scraping to gather data from websites for indexing and ranking purposes.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it generally recommended to initialize the weights (W's) in a neural network using a Gaussian random distribution during the random initialization process?
#
#     ### Response:
#     Yes, it is a common practice to initialize the weights in a neural network using a Gaussian random distribution during the random initialization process.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How is padding useful in image processing?
#
#     ### Response:
#     Padding is used to increase the size of an image, allowing for more context to be considered during processing.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the difference between Natural Language Processing and speech processing?
#
#     ### Response:
#     Natural Language Processing (NLP) focuses on understanding and manipulating human language, while speech processing deals with analyzing and interpreting spoken language.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How can we ensure that models consider external factors, such as the COVID-19 pandemic, which caused sales to decline and no sales during lockdowns?
#
#     ### Response:
#     Including external factors in the model's training data can help it learn to adapt to changing conditions and make more accurate predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are different activation functions in a NN?
#
#     ### Response:
#     Activation functions are non-linear functions that are used to introduce non-linearity in neural networks, allowing them to model complex relationships in data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is convolution primarily used to reduce
# dimensionality in neural networks?
#
#     ### Response:
#     Yes, convolution is frequently used
# to reduce the dimensionality of
# data in neural networks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     During the preprocessing of data, how can anomalies be identified?
#
#     ### Response:
#     Anomalies can be identified by analyzing the data and looking for unusual or unexpected patterns or values.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How important is data mining in the context of machine learning and artificial intelligence?
#
#     ### Response:
#     Data mining is a crucial component of machine learning and AI, as it enables the extraction of valuable insights and patterns from large datasets.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the reason behind choosing max pooling instead of average pooling?
#
#     ### Response:
#     Max pooling is often preferred over average pooling because it helps to preserve the most significant features in the data, leading to better classification performance.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     does the 1st dense includes 1 hidden layer alongwith input layer or just input layer?
#
#     ### Response:
#     The first dense layer in a neural network typically includes both the input layer and a hidden layer.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Compare Gassian random distribution against other methods of intialization?
#
#     ### Response:
#     Gaussian random distribution is a popular method for initializing weights in neural networks, as it helps to break symmetry and avoid local minima.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     does this data thumb rule apply for both classification & regression problems?
#
#     ### Response:
#     The data thumb rule for the number of observations to features ratio is a general guideline that applies to both classification and regression problems.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How does the mapping from a 2x2 input to a 3x3 output occur during sliding in convolutional operations?
#
#     ### Response:
#     The 3x3 output is created by taking a 3x3 window and sliding it over the 2x2 input, resulting in a 3x3 output.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can it be controlled by human?
#
#     ### Response:
#     No, GANs are not directly controlled by humans.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Give one example where y_pred is used?
#
#     ### Response:
#     y_pred is used in machine learning to predict the output of a model for a given input.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does dataset need to have same number of samples in each class for model training?
#
#     ### Response:
#     No, the dataset does not need to have the same number of samples in each class for model training.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How to ensure models consider external impacts like COVID-related sales decline during lockdowns?
#
#     ### Response:
#     Including external factors such as COVID-related sales decline in the model can help ensure that the model considers external impacts and provides more accurate predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the applications of Autoencoder and PCA?
#
#     ### Response:
#     Autoencoders are used for data compression and feature extraction, while PCA is used for dimensionality reduction and feature extraction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How to leverage pretrained models for any specific machine learning task?
#
#     ### Response:
#     Pre-trained models can be fine-tuned for specific tasks by adjusting the model's parameters and adding task-specific layers.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Whether the "images" in later layers of a CNN are actually images or just interpreted as images due to RGB logic?
#
#     ### Response:
#     The "images" in later layers of a CNN are not actual images, but rather feature maps that represent the extracted patterns and characteristics of the input data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is deep learning only used for classification problems?
#
#     ### Response:
#     No, deep learning can be applied to a wide range of tasks, including classification, regression, and clustering.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is there any sub-branch of Speech recognition deals with converting brain electrical signals to speech ?
#
#     ### Response:
#     Yes, there is a sub-branch of speech recognition called electroencephalography (EEG) that deals with converting brain electrical signals to speech.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When or where do Validating constraints or rules such as height-weight ratios, volume-density relationships, or any other domain-specific constraints in a neural network takes place?
#
#     ### Response:
#     Validating constraints or rules in neural networks can be applied at different stages of the model development process, including during model design, data preparation, and model training.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it possible for a model to fail in properly grouping certain data points? What steps should be taken in such a scenario?
#
#     ### Response:
#     Yes, it is possible for a model to fail in properly grouping certain data points. This can be due to overfitting, underfitting, or bias in the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How does the mapping from a 2x2 to a 3x3 size occur during the sliding process?
#
#     ### Response:
#     The 2x2 input is expanded to a 3x3 size by adding two additional pixels on each side, allowing for a 3x3 filter to be applied during the sliding process.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the difference between NLP and speech processing?
#
#     ### Response:
#     NLP focuses on understanding and analyzing text data, while speech processing deals with analyzing and understanding spoken language.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is data normalization/scaling applicable in the context of speech recognition?
#
#     ### Response:
#     Data normalization/scaling can be beneficial in speech recognition tasks, as it can help to reduce the impact of outliers and improve the performance of the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In CNNs, how can we visualize layers and filters? Do we interpret the weights as RGB pixel values, and how do we handle values beyond the 0-255 range? Maintain the context in the rephrased question.
#
#     ### Response:
#     In CNNs, we can visualize the filters and layers by interpreting the weights as RGB pixel values. However, we need to normalize the values to the 0-255 range for better visualization.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How we can load bin file?
#
#     ### Response:
#     Bin files can be loaded using the load() function in Python.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the reasons for using max pooling instead of average pooling? Provide insights into the context of choosing max pooling.
#
#     ### Response:
#     Max pooling is often preferred over average pooling because it helps to preserve the most significant features in the data, which can be useful for classification tasks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the purpose of using a limit or max limit in a given context?
#
#     ### Response:
#     Limiting the number of elements in a set or sequence can help to reduce complexity and improve performance.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is clustering a suitable technique for determining the optimal placement of Content Delivery Networks (CDNs) in cloud infrastructure?
#
#     ### Response:
#     Yes, clustering can be used to identify the optimal locations for CDNs in cloud infrastructure.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Mention few methods used for cutting neural networks?
#
#     ### Response:
#     Pruning, Quantization, and Distillation are some methods used for cutting neural networks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does Unsupervised Learning solely apply to 'grouping' or 'clustering'? Are there other applications for unsupervised learning?
#
#     ### Response:
#     Unsupervised learning is a type of machine learning that focuses on discovering patterns and relationships in data without the need for labeled training data. It can be used for a variety of tasks, including clustering, anomaly detection, and feature extraction.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How do discrimination and reliability differ from each other?
#
#     ### Response:
#     Discrimination refers to the ability of a model to correctly classify samples, while reliability refers to the model's ability to consistently produce accurate predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Which holds more signficance: classification or regression?
#
#     ### Response:
#     Both classification and regression are important in machine learning, depending on the problem at hand.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it recommended to use MATLAB for speech processing?
#
#     ### Response:
#     Yes, MATLAB is a powerful tool for speech processing, providing a range of built-in functions and toolboxes for tasks such as feature extraction, classification, and analysis.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it always feasible to transform data to a linearly separable form by increasing the dimensionality by one?
#
#     ### Response:
#     No, increasing the dimensionality by one may not always result in a linearly separable form.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How does window size parameter affect the context of a given word in NLP?
#
#     ### Response:
#     The window size parameter in NLP determines the context of a word by considering the surrounding words within a certain range.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it necessary to comprehend the features
# extracted by CNN or can we simply feed
# them into Random Forest and let the
# machine handle the task?
# Why is backpropagation not applicable to
# Random Forest, and what are the reasons behind it?
#
#     ### Response:
#     Random Forest is a non-parametric
# algorithm that does not require
# backpropagation. It uses bagging to
# create multiple decision trees, each
# trained on a different subset of the
# data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     How do any constraint/rules like height weight ,or volume density,fit etc can be validated in neural networks, at which layer?
#
#     ### Response:
#     Constraints like height, weight, volume, and density can be validated in neural networks at the input layer, where they are used to transform the input data into a suitable format for the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can self-supervised learning be the apt approach for fraud detection where count of true positives is very low in reality?
#
#     ### Response:
#     Self-supervised learning can be an effective approach for fraud detection, as it can extract meaningful representations from unlabeled data and identify patterns that may indicate fraudulent activity.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In simple terms, how is feedback different from backpropagation in the context of neural networks?
#
#     ### Response:
#     Backpropagation is a method used to update the weights in a neural network, while feedback refers to the process of providing information about the model's performance to the user.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it appropriate to interpret the weights as RGB pixel values? What occurs when certain numbers exceed the 0-255 range?
#
#     ### Response:
#     No, the weights are not directly related to RGB pixel values. They are used to represent the importance of each feature in the model.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can RGBa images be considered as a 4D array in image processing?
#
#     ### Response:
#     Yes, RGBa images can be considered as a 4D array in image processing, where the 4th dimension represents the alpha channel.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What are the differences between using batch training and stochastic gradient descent (SGD) in neural network optimization? Maintain the context in the rephrased question.
#
#     ### Response:
#     Batch training refers to training the model on a fixed number of samples at once, while SGD trains the model on a single sample at a time.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     what does X.ndim do in pytorch? What is the equivalent function in tensorflow package?
#
#     ### Response:
#     X.ndim in PyTorch refers to the number of dimensions in a tensor. The equivalent function in TensorFlow is tf.shape, which returns the shape of a tensor as a tuple.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Will slow compression over many layers & abrupt expansion over few layers lead to data loss in autoencoder?
#
#     ### Response:
#     Yes, it is possible that slow compression over many layers and abrupt expansion over few layers can lead to data loss in an autoencoder.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can FAQ bots be developed or constructed using Interactive ML?
#
#     ### Response:
#     Yes, FAQ bots can be developed using Interactive ML, which involves collecting and analyzing user interactions to improve the bot's responses over time.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does user controls the number of features to be selected in each tree of a Random Forest model a hyperparameter ?
#
#     ### Response:
#     Yes, the number of features to be considered at each split in a Random Forest model is a hyperparameter that can be tuned to improve model performance.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When is backpropagation performed in neural networks, and what is its role in the learning process? Maintain the context in the rephrased question.
#
#     ### Response:
#     Backpropagation is a method used to update the weights in neural networks during the training process. It helps the network learn from its mistakes and improve its predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the primary challenge in current NLP research that researchers are actively working to overcome?
#
#     ### Response:
#     The primary challenge in current NLP research is the ability to understand and generate human-like responses in natural language.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is MSE the only loss function used for
# time series, or can other loss functions
# also be applied?
#
#     ### Response:
#     Yes, other loss functions can be used
# for time series analysis, such as
# mean absolute error (MAE) and
# mean absolute percentage error
# (MAPE).<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     where do we use cartesian?
#
#     ### Response:
#     Cartesian coordinates are used to represent a point in a two-dimensional space by specifying its x and y coordinates.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the cross Entropy loss? Is that same as Misclassfication rate?
#
#     ### Response:
#     Cross-entropy loss is a measure of the difference between the predicted and actual probabilities, while misclassification rate is a measure of the proportion of incorrect predictions.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     What is the significance of data mining with ML and AI? How does it differ from traditional data mining, where predictions are left to humans, while ML can make predictions for humans?
#
#     ### Response:
#     Data mining with ML and AI is a more advanced approach that uses algorithms to automatically extract patterns and insights from data, making predictions and recommendations without human intervention.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does backpropagation occur exclusively in the fully connected layer, or does it involve other layers in the neural network? Maintain the context in the rephrased question.
#
#     ### Response:
#     Backpropagation is a technique used to update the weights in the neural network, and it can occur in any layer, including fully connected layers, convolutional layers, and recurrent layers.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is it ideal for autoencoders to be symmetric? Could slow compression over many layers and abrupt expansion over a few layers lead to data loss?
#
#     ### Response:
#     Yes, it is ideal for autoencoders to be symmetric, as it helps to avoid data loss and ensures that the input and output dimensions are the same.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can autoencoders be used as a dimensionality reduction tool, similar to PCA, in supervised learning scenarios?
#
#     ### Response:
#     Yes, autoencoders can be used as a dimensionality reduction tool in supervised learning scenarios, as they can extract relevant features and reduce the input data's dimension.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Can you repeat difference between data mining and machine learning
#
#     ### Response:
#     Data mining is a process of discovering patterns and relationships in large datasets, while machine learning is a subset of AI that focuses on building algorithms that can learn and make predictions based on data.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Is there any software available for clinical language annotation?
#
#     ### Response:
#     Yes, there are several tools available for clinical language annotation, such as the Clinical Text Annotation (CTA) tool, which is designed specifically for clinical text annotation.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     When do we slice?
#
#     ### Response:
#     Slicing is used to extract a specific part of an array or tensor.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     In terms of obtaining better context, is lemmatization generally considered superior to stemming?
#
#     ### Response:
#     In general, lemmatization is considered to be a more effective approach than stemming for obtaining better context in natural language processing tasks.<eos>
# <bos>Below is an instruction that describes a task.     Write a response that appropriately completes the request.
#
#     ### Instruction:
#     Generate an answer for the following question in less than two sentences.
#
#     ### Input:
#     Does the kernel provide information about the higher dimension count?
#
#     ### Response:
#     The kernel in a neural network provides information about the number of filters or channels in each layer.<eos>
#                                               answer-2  \
# 0    To effectively convert 2D images to 1D, use te...
# 1    Yes, autoencoders can be used for dimensionali...
# 2    NLP models struggle with tasks that require re...
# 3    Neural networks are powerful, but they may str...
# 4    Scaling the input data is advisable when utili...
# ..                                                 ...
# 115  Machine learning is a subset of data mining th...
# 116  CLAMP is a comprehensive clinical Natural Lang...
# 117  Slicing can be useful for working with large d...
# 118  Yes,Unlike stemming, which simply trims words ...
# 119  No. The kernel is a function used in machine l...
#
#                                          gemma_answers
# 0    Reshaping the 2D image into a 1D vector is a c...
# 1    Yes, an autoencoder can be used for dimensiona...
# 2    The biggest challenge in NLP is dealing with t...
# 3    Neural networks can solve a wide range of prob...
# 4    Yes, scaling is necessary for SVM to ensure th...
# ..                                                 ...
# 115  Data mining is a process of discovering patter...
# 116  Yes, there are several tools available for cli...
# 117  Slicing is used to extract a specific part of ...
# 118  In general, lemmatization is considered to be ...
# 119  The kernel in a neural network provides inform...
#
# [120 rows x 2 columns]

# %%
D1_test_scores_A2 = D1_Test_Gemma_with_Unsloth_df_A2.copy()

# %%
D1_test_scores_A2['rouge_scores'] = D1_test_scores_A2.apply(lambda row: calculate_rouge(row['answer-2'], row['gemma_answers']), axis=1)

# %%
D1_test_scores_A2 = pd.concat([D1_test_scores_A2, pd.json_normalize(D1_test_scores_A2['rouge_scores'])], axis=1)

# %%
D1_test_scores_A2
# Out:
#                                               answer-2  \
# 0    To effectively convert 2D images to 1D, use te...
# 1    Yes, autoencoders can be used for dimensionali...
# 2    NLP models struggle with tasks that require re...
# 3    Neural networks are powerful, but they may str...
# 4    Scaling the input data is advisable when utili...
# ..                                                 ...
# 115  Machine learning is a subset of data mining th...
# 116  CLAMP is a comprehensive clinical Natural Lang...
# 117  Slicing can be useful for working with large d...
# 118  Yes,Unlike stemming, which simply trims words ...
# 119  No. The kernel is a function used in machine l...
#
#                                          gemma_answers  \
# 0    Reshaping the 2D image into a 1D vector is a c...
# 1    Yes, an autoencoder can be used for dimensiona...
# 2    The biggest challenge in NLP is dealing with t...
# 3    Neural networks can solve a wide range of prob...
# 4    Yes, scaling is necessary for SVM to ensure th...
# ..                                                 ...
# 115  Data mining is a process of discovering patter...
# 116  Yes, there are several tools available for cli...
# 117  Slicing is used to extract a specific part of ...
# 118  In general, lemmatization is considered to be ...
# 119  The kernel in a neural network provides inform...
#
#                                           rouge_scores    rouge1    rouge2  \
# 0    {'rouge1': 0.45833333333333326, 'rouge2': 0.21...  0.458333  0.217391
# 1    {'rouge1': 0.6415094339622641, 'rouge2': 0.431...  0.641509  0.431373
# 2    {'rouge1': 0.16326530612244897, 'rouge2': 0.0,...  0.163265  0.000000
# 3    {'rouge1': 0.18181818181818182, 'rouge2': 0.04...  0.181818  0.047619
# 4    {'rouge1': 0.25, 'rouge2': 0.0, 'rougeL': 0.21...  0.250000  0.000000
# ..                                                 ...       ...       ...
# 115  {'rouge1': 0.53125, 'rouge2': 0.25806451612903...  0.531250  0.258065
# 116  {'rouge1': 0.16326530612244897, 'rouge2': 0.0,...  0.163265  0.000000
# 117  {'rouge1': 0.3870967741935484, 'rouge2': 0.0, ...  0.387097  0.000000
# 118  {'rouge1': 0.18181818181818182, 'rouge2': 0.0,...  0.181818  0.000000
# 119  {'rouge1': 0.30434782608695654, 'rouge2': 0.04...  0.304348  0.045455
#
#        rougeL  rougeLsum
# 0    0.250000   0.250000
# 1    0.641509   0.641509
# 2    0.163265   0.163265
# 3    0.181818   0.181818
# 4    0.214286   0.214286
# ..        ...        ...
# 115  0.375000   0.375000
# 116  0.122449   0.122449
# 117  0.322581   0.322581
# 118  0.109091   0.109091
# 119  0.217391   0.217391
#
# [120 rows x 7 columns]

# %%
D1_test_scores_A2['bleu_score'] = D1_test_scores_A2.apply(lambda row: calculate_bleu(row['answer-2'], row['gemma_answers']), axis=1)


D1_test_scores_A2['meteor_score'] = D1_test_scores_A2.apply(lambda row: calculate_meteor(row['answer-2'], row['gemma_answers']), axis=1)

# %%
D1_test_scores_A2
# Out:
#                                               answer-2  \
# 0    To effectively convert 2D images to 1D, use te...
# 1    Yes, autoencoders can be used for dimensionali...
# 2    NLP models struggle with tasks that require re...
# 3    Neural networks are powerful, but they may str...
# 4    Scaling the input data is advisable when utili...
# ..                                                 ...
# 115  Machine learning is a subset of data mining th...
# 116  CLAMP is a comprehensive clinical Natural Lang...
# 117  Slicing can be useful for working with large d...
# 118  Yes,Unlike stemming, which simply trims words ...
# 119  No. The kernel is a function used in machine l...
#
#                                          gemma_answers  \
# 0    Reshaping the 2D image into a 1D vector is a c...
# 1    Yes, an autoencoder can be used for dimensiona...
# 2    The biggest challenge in NLP is dealing with t...
# 3    Neural networks can solve a wide range of prob...
# 4    Yes, scaling is necessary for SVM to ensure th...
# ..                                                 ...
# 115  Data mining is a process of discovering patter...
# 116  Yes, there are several tools available for cli...
# 117  Slicing is used to extract a specific part of ...
# 118  In general, lemmatization is considered to be ...
# 119  The kernel in a neural network provides inform...
#
#                                           rouge_scores    rouge1    rouge2  \
# 0    {'rouge1': 0.45833333333333326, 'rouge2': 0.21...  0.458333  0.217391
# 1    {'rouge1': 0.6415094339622641, 'rouge2': 0.431...  0.641509  0.431373
# 2    {'rouge1': 0.16326530612244897, 'rouge2': 0.0,...  0.163265  0.000000
# 3    {'rouge1': 0.18181818181818182, 'rouge2': 0.04...  0.181818  0.047619
# 4    {'rouge1': 0.25, 'rouge2': 0.0, 'rougeL': 0.21...  0.250000  0.000000
# ..                                                 ...       ...       ...
# 115  {'rouge1': 0.53125, 'rouge2': 0.25806451612903...  0.531250  0.258065
# 116  {'rouge1': 0.16326530612244897, 'rouge2': 0.0,...  0.163265  0.000000
# 117  {'rouge1': 0.3870967741935484, 'rouge2': 0.0, ...  0.387097  0.000000
# 118  {'rouge1': 0.18181818181818182, 'rouge2': 0.0,...  0.181818  0.000000
# 119  {'rouge1': 0.30434782608695654, 'rouge2': 0.04...  0.304348  0.045455
#
#        rougeL  rougeLsum  bleu_score  meteor_score
# 0    0.250000   0.250000    2.024446      0.309722
# 1    0.641509   0.641509    1.646664      0.394681
# 2    0.163265   0.163265    0.000000      0.104712
# 3    0.181818   0.181818    0.000000      0.099053
# 4    0.214286   0.214286    1.727224      0.101744
# ..        ...        ...         ...           ...
# 115  0.375000   0.375000    0.996419      0.496528
# 116  0.122449   0.122449    0.000000      0.107296
# 117  0.322581   0.322581    0.000000      0.274052
# 118  0.109091   0.109091    1.573293      0.080645
# 119  0.217391   0.217391    2.024446      0.129630
#
# [120 rows x 9 columns]

# %%
A2_average_scores = {
    'average_rouge1': D1_test_scores_A2['rouge1'].mean(),
    'average_rouge2': D1_test_scores_A2['rouge2'].mean(),
    'average_rougeL': D1_test_scores_A2['rougeL'].mean(),
    'average_rougeLsum': D1_test_scores_A2['rougeLsum'].mean(),
    'average_bleu_score': D1_test_scores_A2['bleu_score'].mean(),
    'average_meteor_score': D1_test_scores_A2['meteor_score'].mean(),
}

# %%
print("Average Scores for Dataset-1 (Test-Answer-2) QnA task using Gemma_7b_with_Unsloth model:\n")
for metric, score in A2_average_scores.items():
    print(f"{metric}: {score:.4f}")
# Out:
# Average Scores for Dataset-1 (Test-Answer-2) QnA task using Gemma_7b_with_Unsloth model:
#
# average_rouge1: 0.3936
# average_rouge2: 0.1651
# average_rougeL: 0.3156
# average_rougeLsum: 0.3196
# average_bleu_score: 0.7327
# average_meteor_score: 0.2583

# %%
# make a df with A2_average_scores and average_scores

# Create a DataFrame from the dictionaries
D1_Test_Scores = pd.DataFrame([average_scores, A2_average_scores], index=['Answer-1', 'Answer-2'])

# Transpose the DataFrame for better readability
D1_Test_Scores = D1_Test_Scores.T

D1_Test_Scores
# Out:
#                       Answer-1  Answer-2
# average_rouge1        0.419145  0.393645
# average_rouge2        0.187985  0.165117
# average_rougeL        0.336342  0.315571
# average_rougeLsum     0.339513  0.319638
# average_bleu_score    0.985344  0.732727
# average_meteor_score  0.284824  0.258258
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# D1_Test_Scores['Answer-1'].plot(kind='hist', bins=20, title='Answer-1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# D1_Test_Scores['Answer-2'].plot(kind='hist', bins=20, title='Answer-2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# D1_Test_Scores.plot(kind='scatter', x='Answer-1', y='Answer-2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# D1_Test_Scores['Answer-1'].plot(kind='line', figsize=(8, 4), title='Answer-1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# D1_Test_Scores['Answer-2'].plot(kind='line', figsize=(8, 4), title='Answer-2')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# scores_df.to_csv('evaluation_results.csv', index=False)

# %%
# from huggingface_hub import create_repo, HfApi,login


# login(token="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")  # Replace with your Hugging Face API token


# # # Authenticate
# # api = HfApi()
# # api.login(token="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")  # Replace with your Hugging Face API token

# # Create a new repository
# repo_name = "Lohith9459/gemma7b"  # Replace with your repository name
# # create_repo(repo_name, repo_type="model")  # or repo_type="dataset" for datasets

# print(f"Repository created: https://huggingface.co/{repo_name}")

# %%
# model.push_to_hub("Lohith9459/gemma7b", token = "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")

# %%
# tokenizer.push_to_hub("Lohith9459/gemma7b", token = "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")

# %%
# adapter_config ="/content/G15_finetuned_gemma/adapter_config.json"

# %%
# from transformers import AutoConfig

# %%
# adapter_config = AutoConfig.from_pretrained("/content/G15_finetuned_gemma/adapter_config.json")
# adapter_config.push_to_hub("Lohith9459/gemma7b", token = "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")

# %%
# !pip install -q gradio torch transformers accelerate

# %%
# def generate_subject(email_body):
#   instruction = "Generate a subject line for the following email."
#   formatted_text = f"""Below is an instruction that describes a task. \
#     Write a response that appropriately completes the request.

#     ### Instruction:
#     {instruction}

#     ### Input:
#     {email_body}

#     ### Response:
#     """
#   inputs = tokenizer([formatted_text], return_tensors="pt").to("cuda")
#   text_streamer = TextStreamer(tokenizer)
#   generated_ids = model.generate(**inputs, streamer=text_streamer, max_new_tokens=512)
#   generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True)

#   def extract_subject(text):
#     start_tag = "### Response:"
#     start_idx = text.find(start_tag)
#     if start_idx == -1:
#         return None
#     subject = text[start_idx + len(start_tag):].strip()
#     return subject

#   return extract_subject(generated_text)

# # Create the Gradio interface
# demo = gr.Interface(
#     fn=generate_subject,
#     inputs=gr.Textbox(lines=15, label="Email Body"),
#     outputs=gr.Textbox(label="Gemma Generated Subject")
# )

# demo.launch()

# %%
# index = 8
# val_dataset_df['body'][index],val_dataset_df['subject'][index]

# %%
# scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL', 'rougeLsum'], use_stemmer=True)

# # Calculate scores against original subjects
# gemma_model_results = {}
# for pred, ref in zip(original_answer, gemma_answers):
#     scores = scorer.score(ref, pred)  # Note: order is reference, prediction
#     for metric, score in scores.items():
#         if metric not in gemma_model_results:
#             gemma_model_results[metric] = []
#         gemma_model_results[metric].append(score)

# print('Gemma_Answers Vs. Original Answerss:')
# for metric, scores in gemma_model_results.items():
#     avg_precision = sum(s.precision for s in scores) / len(scores)
#     avg_recall = sum(s.recall for s in scores) / len(scores)
#     avg_fmeasure = sum(s.fmeasure for s in scores) / len(scores)
#     print(f"{metric}: Precision={avg_precision:.4f}, Recall={avg_recall:.4f}, F1={avg_fmeasure:.4f}")
